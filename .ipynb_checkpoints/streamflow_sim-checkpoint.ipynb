# %%
import numpy as np
import xarray as xr
import pandas as pd
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import seaborn as sns
import glob
import dask
import matplotlib
import scipy.special as sps  
import xagg as xa
import pickle

# %%
from dask.distributed import Client
client = Client(n_workers=8)
client
# Out:
# distributed.diskutils - INFO - Found stale lock file and directory '/glade/work/elkoukah/empirical/production/analysis/dask-worker-space/worker-3_3lnong', purging
# <Client: 'tcp://127.0.0.1:34063' processes=8 threads=256, memory=235.00 GiB>

# %% [markdown]
# # Preprocess

# %%
def get_obs(indir_obs, inf_qobs, inf_stattrs, tdelta):
    """
    Return stations obs dataset,
    """
    df = pd.read_csv(indir_obs+inf_qobs)
    st_ids = df.iloc[0, 1:].values
    df0 = df.iloc[5:-5]
    df0.columns = ['date']+st_ids.tolist()
    index = pd.to_datetime(df0.date)
    df0.loc[:, 'date'] = index
    df0.rename(columns={'date':'time'}, inplace=True)
    df0.set_index('time', inplace=True)
    df1 = df0.astype('float')
    df_sts = pd.read_csv(indir_obs+inf_stattrs,
                         dtype={'stid':str, 'lon':float, 'lat':float})
    st_ids_eval = df_sts['stid']
    df1_sts = df1.loc[tdelta, st_ids_eval]
    month_length = df1_sts.index.days_in_month.values
    df1_sts = df1_sts/(70.07*month_length[:, np.newaxis]) # m3/s
    qobs = df1_sts.to_xarray()
    df_sts.set_index('stid', inplace=True)
    return qobs, st_ids_eval, df_sts

def read_camels(camels_dir_qobs, camels_coord_file, camels_swus_gaugeid):
    df0 = pd.read_csv(camels_coord_file, delimiter=';', index_col=0)
    df_gid = pd.read_csv(camels_swus_gaugeid)
    df1 = df0.loc[df_gid['gauge_id']]

    huc = ['01','02','03','04','05','06','07','08','09','10','11','12','13','14','15','16','17','18']
    sel_gauges = df1.index.tolist()
    camels_qobs_files = []
    for i in huc:
        files = os.listdir(camels_dir_qobs+i+'/')
        filespath = [camels_dir_qobs+i+'/'+f for f in files if (int(f.split('_')[0]) in sel_gauges)] 
        camels_qobs_files.extend(filespath)

    dfs_list = []
    for fpath in camels_qobs_files:
        gid = os.path.basename(fpath).split('_')[0]
        df0_obs = pd.read_csv(fpath, sep='\s+', names=['gauge_id', 'year', 'month', 'day', int(gid), 'flag'])
        df0_obs['time'] = pd.to_datetime(df0_obs[['year','month','day']])
        df0_obs = df0_obs.set_index('time')
        df0_obs = df0_obs.drop(['gauge_id', 'year','month','day','flag'], axis=1)
        dfs_list.append(df0_obs)

    df_obs = pd.concat(dfs_list, axis=1)
    ds_obs = df_obs.to_xarray()
    return ds_obs.where(ds_obs>=0)

import scipy.special as sps  

def ds_aave_polygon(ds,gdf):
    weightmap = xa.pixel_overlaps(ds,gdf)
    aggregated = xa.aggregate(ds, weightmap)
    ds_aave = aggregated.to_dataset()
    return ds_aave
    
def route(da, shape=2.5, scale=1):
    nt = da.time.size
    t = np.arange(0, nt)
    y = t**(shape-1)*(np.exp(-t/scale) /  
                         (sps.gamma(shape)*scale**shape))
    q = np.convolve(y, da.data[:-1], mode='full')
    q = xr.DataArray(q[:nt-1], dims=('time',), coords={'time':da.time[:nt-1]}, name='Q')
    return q

import xagg as xa
def calc_discharge(casename, roffile, camels_stations, gdf_camels, reclamation_comid_idx, reclamation_stations):
    archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
    print('\n processing:', casename)
    hdir = archive_dir+casename+'/lnd/hist'
    dsh = xr.open_dataset(hdir+'/'+roffile).load()
    print(dsh)
    res = 0.04
    
    # Discharge at Camels
    dict_q = {}
    for basin in camels_stations:
        
        print('area averaging:', basin)
        gdfi = gdf_camels.loc[int(basin)]
        geom = gpd.GeoDataFrame({'tag': [basin], 'geometry': [gdfi.geometry]}, crs="EPSG:4326")
        minx,miny,maxx,maxy = geom.bounds.values[0]
        minx,miny,maxx,maxy = minx-res,miny-res,maxx+res,maxy+res
        # dsh_bounds = dsh.sel(lat=slice(miny,maxy), lon=slice(minx,maxx)).compute()
        dsh_bounds = dsh.sel(lat=slice(miny,maxy), lon=slice(minx+360,maxx+360))
        dsh_aave = ds_aave_polygon(dsh_bounds[['QRUNOFF']], geom)
        
        print('routing runoff:', basin)
        rof = dsh_aave['QRUNOFF'][0]*24*60**2
        discharge = route(rof)
        A = df_attrs_camels.loc[int(basin),'area_gages2']*10**6
        fc = (10**-3)*A/(24*60**2)
        dict_q[basin] = discharge*fc

    # Discharge at reclamation
    def get_ensemble_member(ds, comid_idx=reclamation_comid_idx):
        ds_seg = ds.sel(seg=comid_idx)
        return ds_seg['KWTroutedRunoff']
    rofdir = archive_dir+casename+'/rof/hist'
    print(rofdir)
    dsq = xr.open_mfdataset(rofdir+'/*.h.*.nc', preprocess=get_ensemble_member)
    dsq = dsq.assign_coords({'seg':reclamation_stations}).compute()
    for basin in reclamation_stations:
        q = dsq['KWTroutedRunoff'].sel(seg=basin)
        dict_q[basin] = q.drop_vars('seg')
    ds_q = xr.Dataset(dict_q)
    return ds_q

def calc_mkge(x,y):
    r2 = np.mean((y.T-y.mean()).T*(x-x.mean()))/(y.std()*x.std())
    beta = (y.mean()-x.mean())/x.std()
    sigma = y.std()/x.std()
    mkge = 1 - np.sqrt(((r2-1)**2 + (sigma-1)**2 + beta**2))
    bias = (y.mean()/x.mean() - 1)*100
    return mkge, r2, beta, sigma, bias

def calc_nse(x,y):
    nse = 1 - np.sum((y-x)**2)/np.sum((x-x.mean())**2)
    return nse

# %% [markdown]
# ## CR

# %% [markdown]
# ### Discharge

# %%
# Discharge observations

## Reclamation
indir_obs = '/glade/work/elkoukah/inputs/obs/'
inf_qobs = 'NaturalFlows1906-2020_20221215.csv'
inf_stattrs = 'cr_station_attrs_wgs84.csv'
mdl_varname = 'outflw'
dt = '1M'
tdelta = slice("1912-10-01", "2021-09-30")
qobs, stn_eval, df_sts = get_obs(indir_obs, inf_qobs, inf_stattrs, tdelta)

## CAMELS
camels_coord_file = '/glade/work/elkoukah/inputs/obs/CAMELS/camels_topo.txt'
camels_swus_gaugeid = '/glade/work/elkoukah/inputs/obs/CAMELS/camels_swus_gaugeid.txt'
camels_dir_qobs = '/glade/work/elkoukah/inputs/obs/CAMELS/usgs_streamflow/'
ds_obs_camels = read_camels(camels_dir_qobs, camels_coord_file, camels_swus_gaugeid)
# Out:
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Discharge simulations comids

## Reclamation Stations ids
comids_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/crb_stations_comid.csv')
reclamation_stations = comids_crb['stid'].values
ds_topology = xr.open_dataset('/glade/work/elkoukah/empirical/production/mizuroute//ancillary_data/topology_77032202.nc')
comid_idx = []
for comid in comids_crb['COMID']:
    idx = (ds_topology['segId']==comid).argmax().data
    comid_idx.append(idx)
comid_idx = np.stack(comid_idx)

## CAMELs station ids and basins
camels_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/camels_crb_gauges.csv')
camels_stations = camels_crb['GAGE_ID'].values
gdf_camels = gpd.read_file('/glade/work/elkoukah/inputs/obs/CAMELS/HCDN_nhru_final_671.shp')
gdf_camels = gdf_camels.set_index('hru_id')
camels_coord_file = '/glade/work/elkoukah/inputs/obs/CAMELS/camels_topo.txt'
df_attrs_camels = pd.read_csv(camels_coord_file, delimiter=';', index_col=0)

# %%
# streamflow at stations
flag_calc = False
if flag_calc:
    casename = 'CR_conus404_asmo_newsurfdata_fanrootingdepth.002'
    casename = 'CR_conus404_newsurfdata_default.002'
    roffile = 'QRUNOFF.nc'
    ds_qmdl = calc_discharge(casename, roffile, camels_stations, gdf_camels, comid_idx, reclamation_stations)
    for var in ds_qmdl.data_vars:
        ds_qmdl = ds_qmdl.rename({var:str(var)})
    ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_camels_reclamation.nc'%casename
    ds_qmdl.to_netcdf(ofile)

# %%
# Calculate metrics

# %%
casename = 'CR_conus404_asmo_newsurfdata_fanrootingdepth.002'
# casename = 'CR_conus404_newsurfdata_default.002'

ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_camels_reclamation.nc'%casename
ds_qmdl_opt = xr.open_dataset(ofile)

tdelta = slice('1980-10-01','2020-09-30')

qobs_camels_t = ds_obs_camels.sel(time=tdelta)
t = qobs_camels_t.time
qobs_camels_t = qobs_camels_t.sel(time=(t.dt.month!=2)+(t.dt.day!=29))
qobs_reclamation_t = qobs.sel(time=tdelta)

qmdl_t = ds_qmdl_opt.sel(time=tdelta)
qmdl_t['time'] = qmdl_t.time.astype('datetime64[ns]')

q_metrics = ['mkge', 'r2', 'beta', 'sigma', 'pbias', 'nse', 'nse_wy', 'qsim_mean']
print('calculate streamflow metrics:', q_metrics)
nmetric = len(q_metrics)
stations = np.hstack([camels_stations, reclamation_stations])
nstations = stations.size
df_q_metrics = pd.DataFrame(np.full((nmetric, nstations), np.nan), index=q_metrics, columns=stations)

for station in camels_stations:#[ma_camels]:
    yy = qmdl_t[str(station)]
    xx = qobs_camels_t[station]*0.02832 #from cf/s to m3/s
    
    yy = yy.sel(time=xx.time)
    ma = xx.isnull().data
    yy = yy[~ma]
    xx = xx[~ma]
    xxm = xx.resample(time='1M').mean().data
    yym = yy.resample(time='1M').mean().data
    mkge, r2, beta, sigma, bias = calc_mkge(xxm,yym)
    nse = calc_nse(xxm,yym)
    nse_wy = calc_nse(xx.resample(time='A-SEP').mean().data,
                      yy.resample(time='A-SEP').mean().data)
    qsim_mean = yy.mean().data
    df_q_metrics.loc[:, station] = [mkge, r2, beta, sigma, bias, nse, nse_wy, qsim_mean]
for station in reclamation_stations:#[ma_reclamation]:
    yy = qmdl_t[str(station)]
    xx = qobs_reclamation_t['0%i'%station]
    
    yym = yy.resample(time='1M').mean().data
    xxm = xx.data
    mkge, r2, beta, sigma, bias = calc_mkge(xxm,yym)
    nse = calc_nse(xxm,yym)
    nse_wy = calc_nse(xx.resample(time='A-SEP').mean().data,
                      yy.resample(time='A-SEP').mean().data)
    qsim_mean = yy.mean().data
    df_q_metrics.loc[:, station] = [mkge, r2, beta, sigma, bias, nse, nse_wy, qsim_mean]
ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_metrics_%s-%s.csv'%(casename, tdelta.start[:4], tdelta.stop[:4])
print(ofile)
df_q_metrics.T.to_csv(ofile)

# %%
comids_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/crb_stations_comid.csv', index_col='stid')
reclamation_stations = comids_crb.index.values
camels_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/camels_crb_gauges.csv', index_col='GAGE_ID')
camels_stations = camels_crb.index.values
stations = np.hstack([camels_stations,reclamation_stations])
stations_coords = pd.DataFrame(np.zeros((stations.size, 2)), index=stations, columns=('lat','lon'))
stations_coords.loc[camels_stations] = camels_crb[['LAT','LONG']].loc[camels_stations].values
stations_coords.loc[reclamation_stations] = comids_crb[['lat','lon']].loc[reclamation_stations].values

casename = 'CR_conus404_asmo_newsurfdata_fanrootingdepth.002'
ifile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_metrics_1980-2020.csv'%casename
df_metrics = pd.read_csv(ifile, index_col=0)
df_metrics.loc[stations, ['lat','lon']] = stations_coords.values
df_metrics.to_csv('./out/metrics_opt_cr_101980-092020.csv')

casename = 'CR_conus404_newsurfdata_default.002'
ifile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_metrics_1980-2019.csv'%casename
df_metrics = pd.read_csv(ifile, index_col=0)
df_metrics.loc[stations, ['lat','lon']] = stations_coords.values
df_metrics.to_csv('./out/metrics_base_cr_101980-092019.csv')

# %% [markdown]
# ### Sensitivity to climate

# %%
def calc_streamflow_sensitivity(ppt, temp, q):
    P = ppt.resample(time='A-SEP').mean()
    T = temp.resample(time='A-SEP').mean()
    Q = q.resample(time='A-SEP').mean()

    Panom = (P-P.mean())/P.mean() * 100
    Tanom = (T-T.mean())
    Qanom = (Q-Q.mean())/Q.mean() * 100

    X = np.stack([Panom.data[:],
                  Tanom.data[:],
                  np.ones((Panom.size))
                 ])
    Y = Qanom.data[:]
    # reg = linear_model.LinearRegression()
    # reg.fit(X.T, Y)
    # a, b, s = reg.coef_
    a, b, s = np.linalg.lstsq(X.T, Y)[0]
    return a, b

def calc_nse(x,y):
    nse = 1 - np.sum((y-x)**2)/np.sum((x-x.mean())**2)
    return nse

# %%
from shapely.geometry import Polygon

# %%
def gen_polygon_mask(lats, lons, res, geom):
    gridcells = [Polygon(((x-res, y-res), 
                      (x-res, y+res), 
                      (x+res, y+res), 
                      (x+res,y-res), 
                      (x-res, y-res))) for x,y in zip(lons, lats)]
    ngrd = len(gridcells)
    mask = np.zeros((ngrd,), dtype=int)
    for ii in range(ngrd):
        mask[ii] = geom.intersects(gridcells[ii])
    return mask

# %%
import pickle

# %%
# inputs
qens = xr.open_dataset('/glade/derecho/scratch/elkoukah/pipeline/optz-top37_ucrb-0.9x1.25_0.base_daily_discharge_9380000_2.nc')
livneh_dict = pickle.load(open('/glade/derecho/scratch/elkoukah/inputs/livneh/ucrb.pkl', 'rb'))
dict_prism = pickle.load(open('/glade/derecho/scratch/elkoukah/inputs/prism/postprocess/prism_ucrb.pkl', 'rb'))
qobs = xr.open_dataset('/glade/work/elkoukah/inputs/obs/crb_reclamation_natflow.nc')
prism_ppt, prism_temp = dict_prism['prism_ppt'], dict_prism['prism_temp']

# %%
shapfile = '/glade/work/elkoukah/inputs/domain/shapefile/ucrb_epsg4326.shp'
gdf = gpd.read_file(shapfile)
bounds = gdf.bounds.iloc[0]
geom = gdf.geometry

# %%
# Model forcings

# %%
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
casename = 'CR_conus404_asmo_newsurfdata_fanrootingdepth.002'
files = sorted(glob.glob(archive_dir+casename+'/lnd/hist/'+casename+'.clm2.h0.*.nc'))
data_vars = ['RAIN', 'SNOW', 'TBOT']
def preprocess(ds):
    return ds[data_vars]
h0 = xr.open_mfdataset(files, parallel=True, preprocess=preprocess)

# %%
h0['lon'] = h0.lon-360

# %%
h0_bbox = h0.sel(lat=slice(bounds['miny'], bounds['maxy']), 
                 lon=slice(bounds['minx'], bounds['maxx']))

# %%
lons, lats = np.meshgrid(h0_bbox.lon, h0_bbox.lat)
mask = gen_polygon_mask(lats.ravel(), lons.ravel(), 0.02, geom)
mask = xr.DataArray(mask.reshape(lats.shape), dims=(('lat','lon')), name='mask')

# %%
rain_mdl = h0_bbox['RAIN'].where(mask>0).mean(('lon','lat')).compute()
snow_mdl = h0_bbox['SNOW'].where(mask>0).mean(('lon','lat')).compute()
tbot_mdl = h0_bbox['TBOT'].where(mask>0).mean(('lon','lat')).compute()

# %%
ppt = (rain_mdl+snow_mdl)*24*60**2

# %%
## Reclamation Stations ids
comids_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/crb_stations_comid.csv')
ds_topology = xr.open_dataset('/glade/work/elkoukah/empirical/production/mizuroute//ancillary_data/topology_77032202.nc')
comid = comids_crb[comids_crb['stid']==9380000].COMID.values # upper basin outlet comid
comid_idx = (ds_topology['segId']==comid).argmax().data
def get_ensemble_member(ds, comid_idx=comid_idx):
    ds_seg = ds.sel(seg=comid_idx)
    return ds_seg['KWTroutedRunoff']
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
casename = 'CR_conus404_asmo_newsurfdata_fanrootingdepth.002'
rofdir = archive_dir+casename+'/rof/hist/'
ifiles = sorted(glob.glob(rofdir+'/*.h.*nc'))
ds_qopt = xr.open_mfdataset(ifiles, parallel=True, preprocess=get_ensemble_member)

# %%
comids_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/crb_stations_comid.csv')
ds_topology = xr.open_dataset('/glade/work/elkoukah/empirical/production/mizuroute/ancillary_data/topology_77020591.nc')
comid = comids_crb[comids_crb['stid']==9380000].COMID.values # upper basin outlet comid
comid_idx = (ds_topology['segId']==comid).argmax().data
def get_ensemble_member(ds, comid_idx=comid_idx):
    ds_seg = ds.sel(seg=comid_idx)
    return ds_seg['KWTroutedRunoff']
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
casename = '14_conus404_reference.base_001'
rofdir = archive_dir+casename+'/rof/hist/'
ifiles = sorted(glob.glob(rofdir+'/*.h.*nc'))
ds_qbase = xr.open_mfdataset(ifiles, parallel=True, preprocess=get_ensemble_member)

# %%
# Metrics
tdelta = slice('1981-10-01', '2019-09-30')
A = 293569*10**6 #m2

# observed estimates
ppt_obs = prism_ppt.sel(time=tdelta)
temp_obs = prism_temp.sel(time=tdelta)
q_obs = qobs['09380000'].sel(time=tdelta)
alpha_obs, beta_obs = calc_streamflow_sensitivity(ppt_obs, temp_obs, q_obs)
month_length = ppt_obs.time.dt.days_in_month
pbar = (ppt_obs/(month_length*24*60**2)).mean()
rratio_obs = q_obs.mean()/(pbar*A*10**-3)
print(alpha_obs, beta_obs)
# Out:
# 1.4437052055779256 -5.443627561846899
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
# model estimates
ppt_mdl = ppt.sel(time=tdelta)
temp_mdl = tbot_mdl.sel(time=tdelta)
q_mdl = ds_qopt['KWTroutedRunoff'].sel(time=tdelta).compute()
alpha_mdl, beta_mdl = calc_streamflow_sensitivity(ppt_mdl, temp_mdl, q_mdl)
print(alpha_mdl, beta_mdl)
# Out:
# 1.8069337596943411 -1.443119462401359
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
# model estimates
ppt_mdl = ppt.sel(time=tdelta)
temp_mdl = tbot_mdl.sel(time=tdelta)
q_mdl_base = ds_qbase['KWTroutedRunoff'].sel(time=tdelta).compute()
alpha_mdl, beta_mdl = calc_streamflow_sensitivity(ppt_mdl, temp_mdl, q_mdl_base)
print(alpha_mdl, beta_mdl)
# Out:
# 1.1629606477417125 9.486081783559051
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
pbar = ppt_mdl*A*10**-3
rratio_obs = q_obs.mean()/(pbar*A*10**-3)

# %%
yy = q_mdl.resample(time='A-SEP').mean()
yy0 = q_mdl_base.resample(time='A-SEP').mean()
kk = q_obs.resample(time='A-SEP').mean()
xx = ppt_mdl.resample(time='A-SEP').mean()
xx0 = ppt_obs.resample(time='A-SEP').mean()

dyy = (yy-yy.mean())/yy.mean() * 100
dyy0 = (yy0-yy0.mean())/yy0.mean() * 100
dkk = (kk-kk.mean())/kk.mean() * 100
dxx = (xx-xx.mean())/xx.mean() * 100
dxx0 = (xx0-xx0.mean())/xx0.mean() * 100

# %%
dict_sens_cr = {'q_mdl':q_mdl, 'q_mdl_base':q_mdl_base, 'q_obs':q_obs, 'ppt_mdl':ppt_mdl, 'ppt_obs':ppt_obs,
             'dyy':dyy, 'dyy0':dyy0, 'dkk':dkk, 'dxx':dxx, 'dxx0':dxx0}
pickle.dump(dict_sens_cr, open('dict_sens_cr.pkl', 'wb'))

# %%
slope_mdl0, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy0)[0]
slope_mdl, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy)[0]
slope_obs, _ = np.linalg.lstsq(np.stack([dxx0.data,np.ones(dxx0.size)]).T, dkk)[0]
print(slope_mdl0, slope_mdl, slope_obs, (slope_mdl0-slope_obs)/slope_obs, (slope_mdl-slope_obs)/slope_obs)
# Out:
# 0.9976963823169513 1.8320754444611005 1.5647443265441432 -0.3623901583203438 0.17084651682832963
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## CA

# %% [markdown]
# ### Discharge

# %%
import scipy.special as sps  
import xagg as xa

def ds_aave_polygon(ds,gdf):
    weightmap = xa.pixel_overlaps(ds,gdf)
    aggregated = xa.aggregate(ds, weightmap)
    ds_aave = aggregated.to_dataset()
    return ds_aave
def route(da, shape=2.5, scale=1):
    nt = da.time.size
    t = np.arange(0, nt)
    y = t**(shape-1)*(np.exp(-t/scale) /  
                         (sps.gamma(shape)*scale**shape))
    q = np.convolve(y, da.data[:-1], mode='full')
    q = xr.DataArray(q[:nt-1], dims=('time',), coords={'time':da.time[:nt-1]}, name='Q')
    return q

def calc_discharge_ca(casename, roffile, camels_stations, ingdf, comid_idx_ca, cdec_stations):
    archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
    print('\n processing:', casename)
    hdir = archive_dir+casename+'/lnd/hist'
    dsh = xr.open_dataset(hdir+'/'+roffile).load()
    print(dsh)
    res = 0.04
    # Discharge at Camels
    dict_q = {}
    for basin in camels_stations:
        print('area averaging:', basin)
        gdfi = ingdf.loc[int(basin)]
        geom = gpd.GeoDataFrame({'tag': [basin], 'geometry': [gdfi.geometry]}, crs="EPSG:4326")
        minx,miny,maxx,maxy = geom.bounds.values[0]
        minx,miny,maxx,maxy = minx-res,miny-res,maxx+res,maxy+res
        dsh_bounds = dsh.sel(lat=slice(miny,maxy), lon=slice(minx+360,maxx+360))
        dsh_aave = ds_aave_polygon(dsh_bounds[['QRUNOFF']], geom)
        
        print('\nrouting runoff:', basin)
        rof = dsh_aave['QRUNOFF'][0]*24*60**2
        discharge = route(rof)
        A = df_attrs_camels.loc[int(basin),'area_gages2']*10**6
        fc = (10**-3)*A/(24*60**2)
        dict_q[str(basin)] = discharge*fc
    
    # Discharge at reclamation
    print('\nreading discharge:')
    def get_ensemble_member(ds, comid_idx=comid_idx_ca):
        ds_seg = ds.sel(seg=comid_idx)
        return ds_seg['KWTroutedRunoff']
    rofdir = archive_dir+casename+'/rof/hist'
    dsq = xr.open_mfdataset(rofdir+'/*.h.*.nc', preprocess=get_ensemble_member)
    dsq = dsq.assign_coords({'seg':cdec_stations}).compute()
    for basin in cdec_stations:
        q = dsq['KWTroutedRunoff'].sel(seg=basin)
        dict_q[basin] = q.drop_vars('seg')
    ds_q = xr.Dataset(dict_q)
    return ds_q

def calc_mkge(x,y):
    r2 = np.mean((y.T-y.mean()).T*(x-x.mean()))/(y.std()*x.std())
    beta = (y.mean()-x.mean())/x.std()
    sigma = y.std()/x.std()
    mkge = 1 - np.sqrt(((r2-1)**2 + (sigma-1)**2 + beta**2))
    bias = (y.mean()/x.mean() - 1)*100
    return mkge, r2, beta, sigma, bias

def calc_nse(x,y):
    nse = 1 - np.sum((y-x)**2)/np.sum((x-x.mean())**2)
    return nse

def read_camels(camels_dir_qobs, camels_coord_file, gauge_ids):
    df0 = pd.read_csv(camels_coord_file, delimiter=';', index_col=0)
    df1 = df0.loc[gauge_ids]

    huc = ['01','02','03','04','05','06','07','08','09','10','11','12','13','14','15','16','17','18']
    sel_gauges = df1.index.tolist()
    camels_qobs_files = []
    for i in huc:
        files = os.listdir(camels_dir_qobs+i+'/')
        filespath = [camels_dir_qobs+i+'/'+f for f in files if (int(f.split('_')[0]) in sel_gauges)] 
        camels_qobs_files.extend(filespath)

    dfs_list = []
    for fpath in camels_qobs_files:
        gid = os.path.basename(fpath).split('_')[0]
        df0_obs = pd.read_csv(fpath, sep='\s+', names=['gauge_id', 'year', 'month', 'day', int(gid), 'flag'])
        df0_obs['time'] = pd.to_datetime(df0_obs[['year','month','day']])
        df0_obs = df0_obs.set_index('time')
        df0_obs = df0_obs.drop(['gauge_id', 'year','month','day','flag'], axis=1)
        df0_obs = df0_obs.rename(columns={df0_obs.columns[0]:str(df0_obs.columns[0])})
        dfs_list.append(df0_obs)
        

    df_obs = pd.concat(dfs_list, axis=1)
    ds_obs = df_obs.to_xarray()
    return ds_obs.where(ds_obs>=0)


def calc_metrics(qmdl, qobs, stations_id, tdelta):
    cols = ['mkge', 'r2', 'beta', 'alpha', 'pbias', 'nse', 'qsim_mean']
    df_metrics = pd.DataFrame(np.full((len(stations_id), len(cols)), np.nan), 
                     columns=cols, index=stations_id)
    for st in stations_id:
        yy = qmdl[st].sel(time=tdelta).resample(time='1M').mean()
        xx = qobs[st].sel(time=tdelta).resample(time='1M').mean()
        ma = xx.isnull()
        r = ma.sum()/yy.size
        if r>.7:
            print('skip', st, '%.2f'%r)
            continue
        else:
            xx = xx[~ma.data]
            yy = yy[~ma.data]
        mkge, r2, beta, sigma, bias = calc_mkge(xx.data, yy.data)
        nse = calc_nse(xx.data, yy.data)
        qsim_mean = yy.mean().data
        df_metrics.loc[st] = [mkge, r2, beta, sigma, bias, nse, qsim_mean]
    return df_metrics

# %%
# Simulations

# %%
ds_topology = xr.open_dataset('/glade/work/elkoukah/empirical/optimize/opt_camels/routing/ancillary_data/topology_CA.nc')
comids_ca = pd.read_csv('/glade/work/elkoukah/inputs/obs/CDEC_Stations_COMID.csv')
comids_ca = comids_ca.set_index('STA')
comids_ca = comids_ca.drop('CLD')
cdec_stations = comids_ca.index.values
comid_idx = []
for comid in comids_ca['COMID']:
    idx = (ds_topology['segId']==comid).argmax().data
    comid_idx.append(idx)
comid_idx_ca = np.stack(comid_idx)

camels_comid_sw = pd.read_csv('/glade/work/elkoukah/inputs/obs/camels_swus_gauge_comid.csv')
camels_comid_ca = camels_comid_sw[camels_comid_sw['HUC_02']==18]
camels_stations_ca = camels_comid_ca['GAGE_ID'].values

gdf_camels = gpd.read_file('/glade/work/elkoukah/inputs/obs/CAMELS/HCDN_nhru_final_671.shp')
gdf_camels = gdf_camels.set_index('hru_id')
gdf_camels_ca = gdf_camels.loc[camels_comid_ca['GAGE_ID']]

camels_coord_file = '/glade/work/elkoukah/inputs/obs/CAMELS/camels_topo.txt'
df_attrs_camels = pd.read_csv(camels_coord_file, delimiter=';', index_col=0)

# %%
flag_calc = False
if flag_calc:
    casename = 'CA_conus404_asmo_newsurfdata_default.001'
    qbase = calc_discharge_ca(casename, 'QRUNOFF.nc', camels_stations_ca, gdf_camels_ca, comid_idx_ca, cdec_stations)
    
    casename = 'CA_conus404_newsurfdata_asmo.opt_002'
    qopt = calc_discharge_ca(casename, 'QRUNOFF.nc', camels_stations_ca, gdf_camels_ca, comid_idx_ca, cdec_stations)
    
    casename = 'CA_conus404_asmo_newsurfdata_default.001'
    ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_camels_reclamation.nc'%casename
    qbase.to_netcdf(ofile)
    
    casename = 'CA_conus404_newsurfdata_asmo.opt_002'
    ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_camels_reclamation.nc'%casename
    qopt.to_netcdf(ofile)

# %%
casename = 'CA_conus404_asmo_newsurfdata_default.001'
ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_camels_reclamation.nc'%casename
qbase = xr.open_dataset(ofile)

casename = 'CA_conus404_newsurfdata_asmo.opt_002'
ofile = '/glade/derecho/scratch/elkoukah/pipeline/%s_discharge_camels_reclamation.nc'%casename
qopt = xr.open_dataset(ofile)

# %%
# Observations
# indir_ca = '/glade/work/elkoukah/inputs/obs/ca_natflw/'
# st_atts = '/glade/work/elkoukah/inputs/obs/CDEC_Stations.csv'
# df_sts = pd.read_csv(st_atts)
# instids = ['AMA', 'AMF', 'AMK', 'AMN', 'ANM', 'ANT', 'ASP', 'ASS', 'ASV', 'BHN', 'CSN', 'CYO', 'DAV', 'EFC', 'ERS',
#            'EWR', 'FPL', 'FPR', 'FRD', 'FTC', 'FTM', 'FTO', 'FTP', 'KGC', 'KGF', 'KGP', 'KLO', 'KRB', 'KRI', 
#            'KRK', 'KWT', 'MBS', 'MDP', 'MKM', 'MKW', 'MRC', 'MSS', 'NCD', 'NPH', 'OTR', 'OWL', 'PLK', 'PSH', 
#            'RRH', 'SBB', 'SCC', 'SCU', 'SDT', 'SFJ', 'SFR', 'SIS', 'SJF', 'SJM', 'SJU', 'SMU', 'SNS', 'SQS', 'SRS', 
#            'SSP', 'STB', 'SVC', 'SWH', 'TLG', 'TLM', 'TLN', 'TLU', 'TNL', 'TRF', 'WFC', 'WWR', 'YBG', 'YBJ', 'YBM', 'YBS', 'YCB', 'YRS']
# dict_sts = {}
# for stid in instids:
#     df = pd.read_csv(indir_ca+stid+'.csv')
#     index = pd.to_datetime(df['DATE TIME'])
#     df['time'] = index
#     df1 = df.set_index('time')
#     df1[stid] = df1['VALUE']
#     df1[stid][(df1[stid] == '---')] = np.nan
#     df2 = df1[stid].astype('float')
#     month_length = df2.index.days_in_month.values
#     df2 = df2/(70.07*month_length)
#     dict_sts[stid] = df2.to_xarray()
# ds_ca = xr.Dataset(dict_sts)
# ds_ca.to_netcdf('/glade/work/elkoukah/inputs/obs/ca_qnat_full.nc')

# %%
# CDEC
qca = xr.open_dataset('/glade/work/elkoukah/inputs/obs/ca_qnat_full.nc')

# CAMELS
camels_coord_file = '/glade/work/elkoukah/inputs/obs/CAMELS/camels_topo.txt'
camels_swus_gaugeid = '/glade/work/elkoukah/inputs/obs/CAMELS/camels_swus_gaugeid.txt'
camels_dir_qobs = '/glade/work/elkoukah/inputs/obs/CAMELS/usgs_streamflow/'
qobs_camels_ca = read_camels(camels_dir_qobs, camels_coord_file, camels_stations_ca)

station_ids = cdec_stations.tolist()+camels_stations_ca.astype('str').tolist()
qobs = xr.merge([qca, qobs_camels_ca])

tdelta = slice('1980-10-01', '2020-09-30')
df_metrics_base = calc_metrics(qbase, qobs, station_ids, tdelta)
df_metrics_base = df_metrics_base.dropna(axis=0)

df_metrics_opt = calc_metrics(qopt, qobs, station_ids, tdelta)
df_metrics_opt = df_metrics_opt.dropna(axis=0)
# Out:
# skip AMA 0.74
# skip AMK 0.72
# skip BHN 1.00
# skip FTC 0.73
# skip FTM 1.00
# skip FTP 0.70
# skip KGP 0.72
# skip MKW 0.95
# skip OTR 1.00
# skip PLK 0.74
# skip SFJ 1.00
# skip SFR 1.00
# skip SJM 1.00
# skip SJU 1.00
# skip SMU 1.00
# skip SQS 0.84
# skip TLM 0.70
# skip TLU 1.00
# skip YBM 0.72
# skip AMA 0.74
# skip AMK 0.72
# skip BHN 1.00
# skip FTC 0.73
# skip FTM 1.00
# skip FTP 0.70
# skip KGP 0.72
# skip MKW 0.95
# skip OTR 1.00
# skip PLK 0.74
# skip SFJ 1.00
# skip SFR 1.00
# skip SJM 1.00
# skip SJU 1.00
# skip SMU 1.00
# skip SQS 0.84
# skip TLM 0.70
# skip TLU 1.00
# skip YBM 0.72

# %%
df_metrics_base.loc[df_metrics_base.index[:57], 'lat'] = comids_ca.loc[df_metrics_base.index[:57], 'Latitude']
df_metrics_base.loc[df_metrics_base.index[:57], 'lon'] = comids_ca.loc[df_metrics_base.index[:57], 'Longitude']
df_metrics_opt.loc[df_metrics_base.index[:57], 'lat'] = comids_ca.loc[df_metrics_base.index[:57], 'Latitude']
df_metrics_opt.loc[df_metrics_base.index[:57], 'lon'] = comids_ca.loc[df_metrics_base.index[:57], 'Longitude']

# %%
df_metrics_base.to_csv('./out/metrics_base_ca_camels_101980-092020.csv')
df_metrics_opt.to_csv('./out/metrics_opt_ca_camels_101980-092020.csv')

# %% [markdown]
# ### Sensitivity to climate

# %%
def calc_streamflow_sensitivity(ppt, temp, q):
    P = ppt.resample(time='A-SEP').mean()
    T = temp.resample(time='A-SEP').mean()
    Q = q.resample(time='A-SEP').mean()

    Panom = (P-P.mean())/P.mean() * 100
    Tanom = (T-T.mean())
    Qanom = (Q-Q.mean())/Q.mean() * 100

    X = np.stack([Panom.data[:],
                  Tanom.data[:],
                  np.ones((Panom.size))
                 ])
    Y = Qanom.data[:]
    # reg = linear_model.LinearRegression()
    # reg.fit(X.T, Y)
    # a, b, s = reg.coef_
    a, b, s = np.linalg.lstsq(X.T, Y)[0]
    return a, b

def calc_nse(x,y):
    nse = 1 - np.sum((y-x)**2)/np.sum((x-x.mean())**2)
    return nse

from shapely.geometry import Polygon

def gen_polygon_mask(lats, lons, res, geom):
    gridcells = [Polygon(((x-res, y-res), 
                      (x-res, y+res), 
                      (x+res, y+res), 
                      (x+res,y-res), 
                      (x-res, y-res))) for x,y in zip(lons, lats)]
    ngrd = len(gridcells)
    mask = np.zeros((ngrd,), dtype=int)
    for ii in range(ngrd):
        mask[ii] = geom.intersects(gridcells[ii])
    return mask

def ds_aave_polygon(ds,gdf):
    weightmap = xa.pixel_overlaps(ds,gdf)
    aggregated = xa.aggregate(ds, weightmap)
    ds_aave = aggregated.to_dataset()
    return ds_aave

# %%
import pickle

# %%
# Observations

# %%
gdf_ns = gpd.read_file('/glade/work/elkoukah/inputs/domain/shapefile/northern_sierras_amf-sbb-yrs-fto.shp')
gdf_ns = gpd.GeoDataFrame({'basin':['Northern Sierras'], 'geometry':[gdf_ns.unary_union]}, crs='EPSG:4326')
minx, miny, maxx, maxy = gdf_ns.bounds.values[0]

idir = '/glade/derecho/scratch/elkoukah/inputs/prism/postprocess/'
# tmean = xr.load_dataarray(idir+'tmean.nc')
ppt = xr.load_dataarray(idir+'ppt.nc')
ppt_bb = ppt.sel(lat=slice(miny,maxy), lon=slice(minx,maxx)).compute()
prcp_prism = ds_aave_polygon(ppt_bb, gdf_ns)

qca = xr.open_dataset('/glade/work/elkoukah/inputs/obs/ca_qnat_full.nc')
qobs = (qca['AMF']+qca['SBB']+qca['YRS']+qca['FTO'])
# Out:
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# all variables aggregated to polygons!

# %%
# Simulations

# %%
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
casename = 'CA_conus404_newsurfdata_asmo.opt_002'
files = sorted(glob.glob(archive_dir+casename+'/lnd/hist/'+casename+'.clm2.h0.*.nc'))
data_vars = ['RAIN', 'SNOW', 'TBOT']
def preprocess(ds):
    return ds[data_vars]
h0 = xr.open_mfdataset(files, parallel=True, preprocess=preprocess)

h0['lon'] = h0.lon-360

h0_bbox = h0.sel(lat=slice(miny,maxy), 
                 lon=slice(minx, maxx)).compute()
h0_aave = ds_aave_polygon(h0_bbox, gdf_ns)

ppt = (h0_aave['RAIN']+h0_aave['SNOW'])*24*60**2
# Out:
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating RAIN...
# aggregating SNOW...
# aggregating TBOT...
# all variables aggregated to polygons!

# %%
ds_topology = xr.open_dataset('/glade/work/elkoukah/empirical/optimize/opt_camels/routing/ancillary_data/topology_CA.nc')
comids_ca = pd.read_csv('/glade/work/elkoukah/inputs/obs/CDEC_Stations_COMID.csv')
comids_ca = comids_ca.set_index('STA')
comids_ca = comids_ca.drop('CLD')
cdec_stations = comids_ca.index.values
comid_idx = []
for comid in comids_ca['COMID']:
    idx = (ds_topology['segId']==comid).argmax().data
    comid_idx.append(idx)
comid_idx_ca = np.stack(comid_idx)

def get_ensemble_member(ds, comid_idx=comid_idx_ca):
    ds_seg = ds.sel(seg=comid_idx)
    return ds_seg['KWTroutedRunoff']
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'

casename = 'CA_conus404_newsurfdata_asmo.opt_002'
rofdir = archive_dir+casename+'/rof/hist'
dsq = xr.open_mfdataset(rofdir+'/*.h.*.nc', preprocess=get_ensemble_member)
ds_qopt = dsq.assign_coords({'seg':cdec_stations}).compute()

casename = 'CA_conus404_asmo_newsurfdata_default.001'
rofdir = archive_dir+casename+'/rof/hist'
dsq = xr.open_mfdataset(rofdir+'/*.h.*.nc', preprocess=get_ensemble_member)
ds_qbase = dsq.assign_coords({'seg':cdec_stations}).compute()

# %%
qbase = ds_qbase['KWTroutedRunoff'].sel(seg=['AMF','SBB','YRS','FTO']).sum('seg')
qopt = ds_qopt['KWTroutedRunoff'].sel(seg=['AMF','SBB','YRS','FTO']).sum('seg')

gdf_ns_proj = gdf_ns.to_crs("EPSG:5070")
A = gdf_ns_proj.area[0]

# %%
tdelta = slice('1981-10-01', '2019-09-30')
yy = qopt.sel(time=tdelta).resample(time='A-SEP').mean()
yy0 = qbase.sel(time=tdelta).resample(time='A-SEP').mean()
kk = qobs.sel(time=tdelta).resample(time='A-SEP').mean()
xx = ppt.sel(time=tdelta, poly_idx=0).resample(time='A-SEP').mean()
xx0 = prcp_prism['ppt'].sel(time=tdelta, poly_idx=0).resample(time='A-SEP').sum()

dyy = (yy-yy.mean())/yy.mean() * 100
dyy0 = (yy0-yy0.mean())/yy0.mean() * 100
dkk = (kk-kk.mean())/kk.mean() * 100
dxx = (xx-xx.mean())/xx.mean() * 100
dxx0 = (xx0-xx0.mean())/xx0.mean() * 100

# %%
dict_sens_ca = {'qopt':qopt, 'qbase':qbase, 'qobs':qobs, 'ppt':ppt, 'prcp_prism':prcp_prism,
             'dyy':dyy, 'dyy0':dyy0, 'dkk':dkk, 'dxx':dxx, 'dxx0':dxx0}
pickle.dump(dict_sens_ca, open('dict_sens_ca.pkl', 'wb'))

# %%
slope_mdl0, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy0)[0]
slope_mdl, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy)[0]
slope_obs, _ = np.linalg.lstsq(np.stack([dxx0.data,np.ones(dxx0.size)]).T, dkk)[0]
print(slope_mdl0, slope_mdl, slope_obs, (slope_mdl0-slope_obs)/slope_obs, (slope_mdl-slope_obs)/slope_obs)
# Out:
# 1.4328263561861803 1.7940567176747948 1.5245120722340417 -0.06014102329377025 0.17680715708978184
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print('r-ratio (opt):', yy.mean().data*24*3600*1000/(A*xx.mean().data))

print('r-ratio (ref):', yy0.mean().data*24*3600*1000/(A*xx.mean().data))

print('r-ratio (obs):', kk.mean().data*24*3600*1000*365/(A*xx0.mean().data))
# Out:
# r-ratio (opt): 0.44632840792774997
# r-ratio (ref): 0.6413144890620285
# r-ratio (obs): 0.4959251835334923

# %% [markdown]
# ## Southwest

# %%
def search_upstream(outlet_id, elem, nextElem, ):
    # search upstream elements
    id_int = int(outlet_id)
    all_ups_ids = [id_int]
    immediate_ups_ids = np.unique(elem[np.where(nextElem==id_int)])
    all_ups_ids.extend(list(immediate_ups_ids))
    round_num = 0
    print(id_int, immediate_ups_ids)
    while len(immediate_ups_ids) != 0:

        round_num = round_num+1
        print("Round %d. Totally %d elements are found." % (round_num, len(all_ups_ids)))

        # search upstream elem
        immediate_ups_ids_next = []
        for huc_i in immediate_ups_ids:
            immediate_ups_ids_next.extend(list(elem[np.where(nextElem==huc_i)]))
        immediate_ups_ids_next = np.unique(immediate_ups_ids_next)

        # identify if found HUC exists in upstrm_elem
        immediate_ups_ids = [huc for huc in immediate_ups_ids_next if not huc in all_ups_ids]
        all_ups_ids.extend(immediate_ups_ids)
    return all_ups_ids

# %%
catfile = '/glade/work/elkoukah/inputs/mizuroute/cat_pfaf_7_MERIT_Hydro_v07_Basins_v01.shp'
data_cat = gpd.read_file(catfile)
rivfile = '/glade/work/elkoukah/inputs/mizuroute/riv_pfaf_7_MERIT_Hydro_v07_Basins_v01.shp'
data_riv = gpd.read_file(rivfile)

# %%
shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/WBD_14_HU2_Shape/WBDHU2.shp'
gdf_ucrb = gpd.read_file(shapefile)
gdf_ucrb_crs = gdf_ucrb.to_crs(ccrs.PlateCarree())

shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/WBD_15_HU2_Shape/WBDHU2.shp'
gdf_lcrb = gpd.read_file(shapefile)
gdf_lcrb_crs = gdf_lcrb.to_crs(ccrs.PlateCarree())

shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/WBD_18_HU2_Shape/WBDHU2.shp'
gdf_ca = gpd.read_file(shapefile)
gdf_ca_crs = gdf_ca.to_crs(ccrs.PlateCarree())

shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/SWUS_studydomain_epsg4326.shp'
gdf_sw = gpd.read_file(shapefile)
gdf_sw_crs = gdf_sw.to_crs(ccrs.PlateCarree())

# %%
comids_ca = pd.read_csv('/glade/work/elkoukah/inputs/obs/CDEC_Stations_COMID.csv')
comids_ca = comids_ca.set_index('STA')
comids_ca = comids_ca.drop('CLD')
cdec_stations = comids_ca.index.values

ca_opt_metrics = pd.read_csv('./out/metrics_opt_ca_camels_101980-092020.csv', index_col=0)
ca_opt_metrics = ca_opt_metrics.loc[ca_opt_metrics.index.isin(cdec_stations)] # drop camels from CA
cr_opt_metrics = pd.read_csv('./out/metrics_opt_cr_101980-092020.csv', index_col=0)
metrics_southwest_opt = pd.concat([cr_opt_metrics, ca_opt_metrics])

ca_base_metrics = pd.read_csv('./out/metrics_base_ca_camels_101980-092020.csv', index_col=0)
ca_base_metrics = ca_base_metrics.loc[ca_base_metrics.index.isin(cdec_stations)] # drop camels from CA
cr_base_metrics = pd.read_csv('./out/metrics_base_cr_101980-092019.csv', index_col=0)
metrics_southwest_base = pd.concat([cr_base_metrics, ca_base_metrics])

# %%
id_name = 'COMID'
downid_name = 'NextDownID'
elem = data_riv[id_name].values
nextElem = data_riv[downid_name].values

cr_comids = pd.read_csv('/glade/work/elkoukah/inputs/obs/crb_stations_comid.csv')
outlet_ids = cr_comids['COMID'].values

outlet_drainage_ids = {}
for ii in range(outlet_ids.size):
    all_ups_ids = search_upstream(outlet_ids[ii], elem, nextElem,)
    ups_ids = np.unique(all_ups_ids)
    shp_basin = data_cat[data_cat[id_name].isin(ups_ids)]
    idx = cr_comids[cr_comids[id_name]==outlet_ids[ii]]['stid'].values[0]
    outlet_drainage_ids[idx] = shp_basin
    print('cr:',ii)

ca_comids = pd.read_csv('/glade/work/elkoukah/inputs/obs/CDEC_Stations_COMID.csv', index_col='STA')
ca_comids = ca_comids.drop('CLD') # drop lees fery
outlet_ids = ca_comids['COMID'].values
for ii in range(outlet_ids.size):
    all_ups_ids = search_upstream(outlet_ids[ii], elem, nextElem,)
    ups_ids = np.unique(all_ups_ids)
    shp_basin = data_cat[data_cat[id_name].isin(ups_ids)]
    idx = ca_comids[ca_comids[id_name]==outlet_ids[ii]].index[0]
    outlet_drainage_ids[idx] = shp_basin
    print('ca:',ii)

### 
camels_crb = pd.read_csv('/glade/work/elkoukah/inputs/obs/camels_crb_gauges.csv')
camels_stations = camels_crb['GAGE_ID'].values
gdf_camels = gpd.read_file('/glade/work/elkoukah/inputs/obs/CAMELS/HCDN_nhru_final_671.shp')
gdf_camels = gdf_camels.set_index('hru_id')
cr_gdf_camels = gdf_camels.loc[camels_stations][['geometry','AREA']]
for idx in cr_gdf_camels.index:
    outlet_drainage_ids[idx] = cr_gdf_camels.loc[[idx]]
# Out:
# 77032205 [77032206 77033642]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 9 elements are found.
# Round 4. Totally 13 elements are found.
# Round 5. Totally 19 elements are found.
# Round 6. Totally 27 elements are found.
# Round 7. Totally 35 elements are found.
# Round 8. Totally 41 elements are found.
# Round 9. Totally 43 elements are found.
# Round 10. Totally 45 elements are found.
# Round 11. Totally 47 elements are found.
# Round 12. Totally 49 elements are found.
# Round 13. Totally 51 elements are found.
# Round 14. Totally 55 elements are found.
# Round 15. Totally 57 elements are found.
# Round 16. Totally 61 elements are found.
# Round 17. Totally 65 elements are found.
# Round 18. Totally 71 elements are found.
# Round 19. Totally 79 elements are found.
# Round 20. Totally 87 elements are found.
# Round 21. Totally 93 elements are found.
# Round 22. Totally 101 elements are found.
# Round 23. Totally 111 elements are found.
# Round 24. Totally 119 elements are found.
# Round 25. Totally 125 elements are found.
# Round 26. Totally 135 elements are found.
# Round 27. Totally 143 elements are found.
# Round 28. Totally 153 elements are found.
# Round 29. Totally 163 elements are found.
# Round 30. Totally 175 elements are found.
# Round 31. Totally 181 elements are found.
# Round 32. Totally 189 elements are found.
# Round 33. Totally 199 elements are found.
# Round 34. Totally 209 elements are found.
# Round 35. Totally 223 elements are found.
# Round 36. Totally 231 elements are found.
# Round 37. Totally 239 elements are found.
# Round 38. Totally 245 elements are found.
# Round 39. Totally 251 elements are found.
# Round 40. Totally 257 elements are found.
# Round 41. Totally 263 elements are found.
# Round 42. Totally 269 elements are found.
# Round 43. Totally 275 elements are found.
# Round 44. Totally 281 elements are found.
# Round 45. Totally 291 elements are found.
# Round 46. Totally 301 elements are found.
# Round 47. Totally 313 elements are found.
# Round 48. Totally 325 elements are found.
# Round 49. Totally 335 elements are found.
# Round 50. Totally 347 elements are found.
# Round 51. Totally 361 elements are found.
# Round 52. Totally 377 elements are found.
# Round 53. Totally 395 elements are found.
# Round 54. Totally 409 elements are found.
# Round 55. Totally 423 elements are found.
# Round 56. Totally 437 elements are found.
# Round 57. Totally 445 elements are found.
# Round 58. Totally 453 elements are found.
# Round 59. Totally 461 elements are found.
# Round 60. Totally 469 elements are found.
# Round 61. Totally 481 elements are found.
# Round 62. Totally 493 elements are found.
# Round 63. Totally 507 elements are found.
# Round 64. Totally 523 elements are found.
# Round 65. Totally 535 elements are found.
# Round 66. Totally 549 elements are found.
# Round 67. Totally 567 elements are found.
# Round 68. Totally 591 elements are found.
# Round 69. Totally 613 elements are found.
# Round 70. Totally 629 elements are found.
# Round 71. Totally 641 elements are found.
# Round 72. Totally 655 elements are found.
# Round 73. Totally 671 elements are found.
# Round 74. Totally 689 elements are found.
# Round 75. Totally 711 elements are found.
# Round 76. Totally 732 elements are found.
# Round 77. Totally 752 elements are found.
# Round 78. Totally 772 elements are found.
# Round 79. Totally 790 elements are found.
# Round 80. Totally 806 elements are found.
# Round 81. Totally 820 elements are found.
# Round 82. Totally 832 elements are found.
# Round 83. Totally 848 elements are found.
# Round 84. Totally 860 elements are found.
# Round 85. Totally 874 elements are found.
# Round 86. Totally 890 elements are found.
# Round 87. Totally 906 elements are found.
# Round 88. Totally 922 elements are found.
# Round 89. Totally 934 elements are found.
# Round 90. Totally 946 elements are found.
# Round 91. Totally 956 elements are found.
# Round 92. Totally 966 elements are found.
# Round 93. Totally 974 elements are found.
# Round 94. Totally 986 elements are found.
# Round 95. Totally 1000 elements are found.
# Round 96. Totally 1010 elements are found.
# Round 97. Totally 1014 elements are found.
# Round 98. Totally 1016 elements are found.
# Round 99. Totally 1018 elements are found.
# Round 100. Totally 1020 elements are found.
# Round 101. Totally 1022 elements are found.
# Round 102. Totally 1024 elements are found.
# Round 103. Totally 1026 elements are found.
# Round 104. Totally 1028 elements are found.
# Round 105. Totally 1030 elements are found.
# Round 106. Totally 1032 elements are found.
# Round 107. Totally 1034 elements are found.
# Round 108. Totally 1036 elements are found.
# Round 109. Totally 1038 elements are found.
# Round 110. Totally 1040 elements are found.
# Round 111. Totally 1042 elements are found.
# Round 112. Totally 1044 elements are found.
# Round 113. Totally 1046 elements are found.
# Round 114. Totally 1048 elements are found.
# Round 115. Totally 1052 elements are found.
# Round 116. Totally 1058 elements are found.
# Round 117. Totally 1064 elements are found.
# Round 118. Totally 1072 elements are found.
# Round 119. Totally 1080 elements are found.
# Round 120. Totally 1086 elements are found.
# Round 121. Totally 1092 elements are found.
# Round 122. Totally 1102 elements are found.
# Round 123. Totally 1114 elements are found.
# Round 124. Totally 1126 elements are found.
# Round 125. Totally 1142 elements are found.
# Round 126. Totally 1160 elements are found.
# Round 127. Totally 1176 elements are found.
# Round 128. Totally 1190 elements are found.
# Round 129. Totally 1207 elements are found.
# Round 130. Totally 1223 elements are found.
# Round 131. Totally 1237 elements are found.
# Round 132. Totally 1249 elements are found.
# Round 133. Totally 1261 elements are found.
# Round 134. Totally 1277 elements are found.
# Round 135. Totally 1297 elements are found.
# Round 136. Totally 1315 elements are found.
# Round 137. Totally 1331 elements are found.
# Round 138. Totally 1349 elements are found.
# Round 139. Totally 1367 elements are found.
# Round 140. Totally 1393 elements are found.
# Round 141. Totally 1417 elements are found.
# Round 142. Totally 1443 elements are found.
# Round 143. Totally 1465 elements are found.
# Round 144. Totally 1487 elements are found.
# Round 145. Totally 1515 elements are found.
# Round 146. Totally 1541 elements are found.
# Round 147. Totally 1567 elements are found.
# Round 148. Totally 1589 elements are found.
# Round 149. Totally 1605 elements are found.
# Round 150. Totally 1623 elements are found.
# Round 151. Totally 1645 elements are found.
# Round 152. Totally 1663 elements are found.
# Round 153. Totally 1681 elements are found.
# Round 154. Totally 1699 elements are found.
# Round 155. Totally 1715 elements are found.
# Round 156. Totally 1733 elements are found.
# Round 157. Totally 1747 elements are found.
# Round 158. Totally 1765 elements are found.
# Round 159. Totally 1787 elements are found.
# Round 160. Totally 1807 elements are found.
# Round 161. Totally 1831 elements are found.
# Round 162. Totally 1859 elements are found.
# Round 163. Totally 1887 elements are found.
# Round 164. Totally 1913 elements are found.
# Round 165. Totally 1945 elements are found.
# Round 166. Totally 1979 elements are found.
# Round 167. Totally 2015 elements are found.
# Round 168. Totally 2047 elements are found.
# Round 169. Totally 2071 elements are found.
# Round 170. Totally 2089 elements are found.
# Round 171. Totally 2111 elements are found.
# Round 172. Totally 2135 elements are found.
# Round 173. Totally 2159 elements are found.
# Round 174. Totally 2181 elements are found.
# Round 175. Totally 2203 elements are found.
# Round 176. Totally 2231 elements are found.
# Round 177. Totally 2255 elements are found.
# Round 178. Totally 2279 elements are found.
# Round 179. Totally 2301 elements are found.
# Round 180. Totally 2323 elements are found.
# Round 181. Totally 2347 elements are found.
# Round 182. Totally 2373 elements are found.
# Round 183. Totally 2399 elements are found.
# Round 184. Totally 2423 elements are found.
# Round 185. Totally 2449 elements are found.
# Round 186. Totally 2471 elements are found.
# Round 187. Totally 2491 elements are found.
# Round 188. Totally 2511 elements are found.
# Round 189. Totally 2540 elements are found.
# Round 190. Totally 2576 elements are found.
# Round 191. Totally 2612 elements are found.
# Round 192. Totally 2642 elements are found.
# Round 193. Totally 2672 elements are found.
# Round 194. Totally 2692 elements are found.
# Round 195. Totally 2708 elements are found.
# Round 196. Totally 2724 elements are found.
# Round 197. Totally 2744 elements are found.
# Round 198. Totally 2766 elements are found.
# Round 199. Totally 2780 elements are found.
# Round 200. Totally 2788 elements are found.
# Round 201. Totally 2798 elements are found.
# Round 202. Totally 2812 elements are found.
# Round 203. Totally 2832 elements are found.
# Round 204. Totally 2852 elements are found.
# Round 205. Totally 2870 elements are found.
# Round 206. Totally 2886 elements are found.
# Round 207. Totally 2902 elements are found.
# Round 208. Totally 2922 elements are found.
# Round 209. Totally 2950 elements are found.
# Round 210. Totally 2974 elements are found.
# Round 211. Totally 3000 elements are found.
# Round 212. Totally 3020 elements are found.
# Round 213. Totally 3044 elements are found.
# Round 214. Totally 3070 elements are found.
# Round 215. Totally 3100 elements are found.
# Round 216. Totally 3128 elements are found.
# Round 217. Totally 3168 elements are found.
# Round 218. Totally 3196 elements are found.
# Round 219. Totally 3224 elements are found.
# Round 220. Totally 3254 elements are found.
# Round 221. Totally 3276 elements are found.
# Round 222. Totally 3294 elements are found.
# Round 223. Totally 3310 elements are found.
# Round 224. Totally 3322 elements are found.
# Round 225. Totally 3334 elements are found.
# Round 226. Totally 3342 elements are found.
# Round 227. Totally 3352 elements are found.
# Round 228. Totally 3362 elements are found.
# Round 229. Totally 3374 elements are found.
# Round 230. Totally 3386 elements are found.
# Round 231. Totally 3404 elements are found.
# Round 232. Totally 3422 elements are found.
# Round 233. Totally 3450 elements are found.
# Round 234. Totally 3482 elements are found.
# Round 235. Totally 3516 elements are found.
# Round 236. Totally 3552 elements are found.
# Round 237. Totally 3600 elements are found.
# Round 238. Totally 3634 elements are found.
# Round 239. Totally 3666 elements are found.
# Round 240. Totally 3700 elements are found.
# Round 241. Totally 3732 elements are found.
# Round 242. Totally 3762 elements are found.
# Round 243. Totally 3794 elements are found.
# Round 244. Totally 3830 elements are found.
# Round 245. Totally 3882 elements are found.
# Round 246. Totally 3922 elements are found.
# Round 247. Totally 3966 elements are found.
# Round 248. Totally 4006 elements are found.
# Round 249. Totally 4044 elements are found.
# Round 250. Totally 4086 elements are found.
# Round 251. Totally 4126 elements are found.
# Round 252. Totally 4166 elements are found.
# Round 253. Totally 4204 elements are found.
# Round 254. Totally 4232 elements are found.
# Round 255. Totally 4268 elements are found.
# Round 256. Totally 4296 elements are found.
# Round 257. Totally 4324 elements are found.
# Round 258. Totally 4356 elements are found.
# Round 259. Totally 4386 elements are found.
# Round 260. Totally 4422 elements are found.
# Round 261. Totally 4458 elements are found.
# Round 262. Totally 4500 elements are found.
# Round 263. Totally 4546 elements are found.
# Round 264. Totally 4586 elements are found.
# Round 265. Totally 4636 elements are found.
# Round 266. Totally 4684 elements are found.
# Round 267. Totally 4734 elements are found.
# Round 268. Totally 4796 elements are found.
# Round 269. Totally 4856 elements are found.
# Round 270. Totally 4918 elements are found.
# Round 271. Totally 4976 elements are found.
# Round 272. Totally 5038 elements are found.
# Round 273. Totally 5100 elements are found.
# Round 274. Totally 5160 elements are found.
# Round 275. Totally 5216 elements are found.
# Round 276. Totally 5264 elements are found.
# Round 277. Totally 5318 elements are found.
# Round 278. Totally 5382 elements are found.
# Round 279. Totally 5440 elements are found.
# Round 280. Totally 5500 elements are found.
# Round 281. Totally 5560 elements are found.
# Round 282. Totally 5635 elements are found.
# Round 283. Totally 5705 elements are found.
# Round 284. Totally 5769 elements are found.
# Round 285. Totally 5839 elements are found.
# Round 286. Totally 5905 elements are found.
# Round 287. Totally 5967 elements are found.
# Round 288. Totally 6029 elements are found.
# Round 289. Totally 6091 elements are found.
# Round 290. Totally 6147 elements are found.
# Round 291. Totally 6201 elements are found.
# Round 292. Totally 6253 elements are found.
# Round 293. Totally 6303 elements are found.
# Round 294. Totally 6337 elements are found.
# Round 295. Totally 6373 elements are found.
# Round 296. Totally 6409 elements are found.
# Round 297. Totally 6457 elements are found.
# Round 298. Totally 6513 elements are found.
# Round 299. Totally 6575 elements are found.
# Round 300. Totally 6627 elements are found.
# Round 301. Totally 6683 elements are found.
# Round 302. Totally 6734 elements are found.
# Round 303. Totally 6794 elements are found.
# Round 304. Totally 6838 elements are found.
# Round 305. Totally 6878 elements are found.
# Round 306. Totally 6928 elements are found.
# Round 307. Totally 6976 elements are found.
# Round 308. Totally 7022 elements are found.
# Round 309. Totally 7072 elements are found.
# Round 310. Totally 7128 elements are found.
# Round 311. Totally 7184 elements are found.
# Round 312. Totally 7234 elements are found.
# Round 313. Totally 7296 elements are found.
# Round 314. Totally 7358 elements are found.
# Round 315. Totally 7428 elements are found.
# Round 316. Totally 7494 elements are found.
# Round 317. Totally 7566 elements are found.
# Round 318. Totally 7636 elements are found.
# Round 319. Totally 7712 elements are found.
# Round 320. Totally 7784 elements are found.
# Round 321. Totally 7862 elements are found.
# Round 322. Totally 7936 elements are found.
# Round 323. Totally 8004 elements are found.
# Round 324. Totally 8062 elements are found.
# Round 325. Totally 8112 elements are found.
# Round 326. Totally 8166 elements are found.
# Round 327. Totally 8218 elements are found.
# Round 328. Totally 8272 elements are found.
# Round 329. Totally 8318 elements are found.
# Round 330. Totally 8358 elements are found.
# Round 331. Totally 8390 elements are found.
# Round 332. Totally 8426 elements are found.
# Round 333. Totally 8468 elements are found.
# Round 334. Totally 8506 elements are found.
# Round 335. Totally 8534 elements are found.
# Round 336. Totally 8562 elements are found.
# Round 337. Totally 8588 elements are found.
# Round 338. Totally 8622 elements are found.
# Round 339. Totally 8650 elements are found.
# Round 340. Totally 8680 elements are found.
# Round 341. Totally 8714 elements are found.
# Round 342. Totally 8754 elements are found.
# Round 343. Totally 8790 elements are found.
# Round 344. Totally 8830 elements are found.
# Round 345. Totally 8872 elements are found.
# Round 346. Totally 8912 elements are found.
# Round 347. Totally 8952 elements are found.
# Round 348. Totally 8998 elements are found.
# Round 349. Totally 9040 elements are found.
# Round 350. Totally 9076 elements are found.
# Round 351. Totally 9112 elements are found.
# Round 352. Totally 9154 elements are found.
# Round 353. Totally 9198 elements are found.
# Round 354. Totally 9240 elements are found.
# Round 355. Totally 9272 elements are found.
# Round 356. Totally 9308 elements are found.
# Round 357. Totally 9358 elements are found.
# Round 358. Totally 9400 elements are found.
# Round 359. Totally 9440 elements are found.
# Round 360. Totally 9488 elements are found.
# Round 361. Totally 9528 elements are found.
# Round 362. Totally 9566 elements are found.
# Round 363. Totally 9596 elements are found.
# Round 364. Totally 9626 elements are found.
# Round 365. Totally 9656 elements are found.
# Round 366. Totally 9686 elements are found.
# Round 367. Totally 9718 elements are found.
# Round 368. Totally 9756 elements are found.
# Round 369. Totally 9790 elements are found.
# Round 370. Totally 9832 elements are found.
# Round 371. Totally 9874 elements are found.
# Round 372. Totally 9906 elements are found.
# Round 373. Totally 9936 elements are found.
# Round 374. Totally 9968 elements are found.
# Round 375. Totally 9988 elements are found.
# Round 376. Totally 10014 elements are found.
# Round 377. Totally 10040 elements are found.
# Round 378. Totally 10060 elements are found.
# Round 379. Totally 10084 elements are found.
# Round 380. Totally 10106 elements are found.
# Round 381. Totally 10138 elements are found.
# Round 382. Totally 10162 elements are found.
# Round 383. Totally 10184 elements are found.
# Round 384. Totally 10208 elements are found.
# Round 385. Totally 10238 elements are found.
# Round 386. Totally 10274 elements are found.
# Round 387. Totally 10310 elements are found.
# Round 388. Totally 10340 elements are found.
# Round 389. Totally 10372 elements are found.
# Round 390. Totally 10394 elements are found.
# Round 391. Totally 10414 elements are found.
# Round 392. Totally 10430 elements are found.
# Round 393. Totally 10440 elements are found.
# Round 394. Totally 10450 elements are found.
# Round 395. Totally 10458 elements are found.
# Round 396. Totally 10468 elements are found.
# Round 397. Totally 10478 elements are found.
# Round 398. Totally 10484 elements are found.
# Round 399. Totally 10490 elements are found.
# Round 400. Totally 10498 elements are found.
# Round 401. Totally 10506 elements are found.
# Round 402. Totally 10514 elements are found.
# Round 403. Totally 10526 elements are found.
# Round 404. Totally 10536 elements are found.
# Round 405. Totally 10548 elements are found.
# Round 406. Totally 10556 elements are found.
# Round 407. Totally 10564 elements are found.
# Round 408. Totally 10572 elements are found.
# Round 409. Totally 10580 elements are found.
# Round 410. Totally 10588 elements are found.
# Round 411. Totally 10598 elements are found.
# Round 412. Totally 10612 elements are found.
# Round 413. Totally 10624 elements are found.
# Round 414. Totally 10638 elements are found.
# Round 415. Totally 10646 elements are found.
# Round 416. Totally 10654 elements are found.
# Round 417. Totally 10658 elements are found.
# Round 418. Totally 10662 elements are found.
# Round 419. Totally 10666 elements are found.
# Round 420. Totally 10668 elements are found.
# Round 421. Totally 10670 elements are found.
# Round 422. Totally 10672 elements are found.
# Round 423. Totally 10674 elements are found.
# cr: 0
# 77029020 [77029021 77029097]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 7 elements are found.
# Round 3. Totally 11 elements are found.
# Round 4. Totally 17 elements are found.
# Round 5. Totally 25 elements are found.
# Round 6. Totally 35 elements are found.
# Round 7. Totally 45 elements are found.
# Round 8. Totally 53 elements are found.
# Round 9. Totally 57 elements are found.
# Round 10. Totally 61 elements are found.
# Round 11. Totally 65 elements are found.
# Round 12. Totally 69 elements are found.
# Round 13. Totally 75 elements are found.
# Round 14. Totally 81 elements are found.
# Round 15. Totally 91 elements are found.
# Round 16. Totally 101 elements are found.
# Round 17. Totally 113 elements are found.
# Round 18. Totally 125 elements are found.
# Round 19. Totally 135 elements are found.
# Round 20. Totally 147 elements are found.
# Round 21. Totally 163 elements are found.
# Round 22. Totally 183 elements are found.
# Round 23. Totally 203 elements are found.
# Round 24. Totally 219 elements are found.
# Round 25. Totally 231 elements are found.
# Round 26. Totally 245 elements are found.
# Round 27. Totally 261 elements are found.
# Round 28. Totally 279 elements are found.
# Round 29. Totally 301 elements are found.
# Round 30. Totally 322 elements are found.
# Round 31. Totally 342 elements are found.
# Round 32. Totally 362 elements are found.
# Round 33. Totally 380 elements are found.
# Round 34. Totally 396 elements are found.
# Round 35. Totally 410 elements are found.
# Round 36. Totally 422 elements are found.
# Round 37. Totally 438 elements are found.
# Round 38. Totally 450 elements are found.
# Round 39. Totally 464 elements are found.
# Round 40. Totally 480 elements are found.
# Round 41. Totally 496 elements are found.
# Round 42. Totally 512 elements are found.
# Round 43. Totally 524 elements are found.
# Round 44. Totally 536 elements are found.
# Round 45. Totally 546 elements are found.
# Round 46. Totally 556 elements are found.
# Round 47. Totally 564 elements are found.
# Round 48. Totally 576 elements are found.
# Round 49. Totally 590 elements are found.
# Round 50. Totally 600 elements are found.
# Round 51. Totally 604 elements are found.
# Round 52. Totally 606 elements are found.
# Round 53. Totally 608 elements are found.
# Round 54. Totally 610 elements are found.
# Round 55. Totally 612 elements are found.
# Round 56. Totally 614 elements are found.
# Round 57. Totally 616 elements are found.
# Round 58. Totally 618 elements are found.
# Round 59. Totally 620 elements are found.
# Round 60. Totally 622 elements are found.
# Round 61. Totally 624 elements are found.
# Round 62. Totally 626 elements are found.
# Round 63. Totally 628 elements are found.
# Round 64. Totally 630 elements are found.
# Round 65. Totally 632 elements are found.
# Round 66. Totally 634 elements are found.
# Round 67. Totally 636 elements are found.
# Round 68. Totally 638 elements are found.
# Round 69. Totally 642 elements are found.
# Round 70. Totally 648 elements are found.
# Round 71. Totally 654 elements are found.
# Round 72. Totally 662 elements are found.
# Round 73. Totally 670 elements are found.
# Round 74. Totally 676 elements are found.
# Round 75. Totally 682 elements are found.
# Round 76. Totally 692 elements are found.
# Round 77. Totally 704 elements are found.
# Round 78. Totally 716 elements are found.
# Round 79. Totally 732 elements are found.
# Round 80. Totally 750 elements are found.
# Round 81. Totally 766 elements are found.
# Round 82. Totally 780 elements are found.
# Round 83. Totally 797 elements are found.
# Round 84. Totally 813 elements are found.
# Round 85. Totally 827 elements are found.
# Round 86. Totally 839 elements are found.
# Round 87. Totally 851 elements are found.
# Round 88. Totally 867 elements are found.
# Round 89. Totally 887 elements are found.
# Round 90. Totally 905 elements are found.
# Round 91. Totally 921 elements are found.
# Round 92. Totally 939 elements are found.
# Round 93. Totally 957 elements are found.
# Round 94. Totally 983 elements are found.
# Round 95. Totally 1007 elements are found.
# Round 96. Totally 1033 elements are found.
# Round 97. Totally 1055 elements are found.
# Round 98. Totally 1077 elements are found.
# Round 99. Totally 1105 elements are found.
# Round 100. Totally 1131 elements are found.
# Round 101. Totally 1157 elements are found.
# Round 102. Totally 1179 elements are found.
# Round 103. Totally 1195 elements are found.
# Round 104. Totally 1213 elements are found.
# Round 105. Totally 1235 elements are found.
# Round 106. Totally 1253 elements are found.
# Round 107. Totally 1271 elements are found.
# Round 108. Totally 1289 elements are found.
# Round 109. Totally 1305 elements are found.
# Round 110. Totally 1323 elements are found.
# Round 111. Totally 1337 elements are found.
# Round 112. Totally 1355 elements are found.
# Round 113. Totally 1377 elements are found.
# Round 114. Totally 1397 elements are found.
# Round 115. Totally 1421 elements are found.
# Round 116. Totally 1449 elements are found.
# Round 117. Totally 1477 elements are found.
# Round 118. Totally 1503 elements are found.
# Round 119. Totally 1535 elements are found.
# Round 120. Totally 1569 elements are found.
# Round 121. Totally 1605 elements are found.
# Round 122. Totally 1637 elements are found.
# Round 123. Totally 1661 elements are found.
# Round 124. Totally 1679 elements are found.
# Round 125. Totally 1701 elements are found.
# Round 126. Totally 1725 elements are found.
# Round 127. Totally 1749 elements are found.
# Round 128. Totally 1771 elements are found.
# Round 129. Totally 1793 elements are found.
# Round 130. Totally 1821 elements are found.
# Round 131. Totally 1845 elements are found.
# Round 132. Totally 1869 elements are found.
# Round 133. Totally 1891 elements are found.
# Round 134. Totally 1913 elements are found.
# Round 135. Totally 1937 elements are found.
# Round 136. Totally 1963 elements are found.
# Round 137. Totally 1989 elements are found.
# Round 138. Totally 2013 elements are found.
# Round 139. Totally 2039 elements are found.
# Round 140. Totally 2061 elements are found.
# Round 141. Totally 2081 elements are found.
# Round 142. Totally 2101 elements are found.
# Round 143. Totally 2130 elements are found.
# Round 144. Totally 2166 elements are found.
# Round 145. Totally 2202 elements are found.
# Round 146. Totally 2232 elements are found.
# Round 147. Totally 2262 elements are found.
# Round 148. Totally 2282 elements are found.
# Round 149. Totally 2298 elements are found.
# Round 150. Totally 2314 elements are found.
# Round 151. Totally 2334 elements are found.
# Round 152. Totally 2356 elements are found.
# Round 153. Totally 2370 elements are found.
# Round 154. Totally 2378 elements are found.
# Round 155. Totally 2388 elements are found.
# Round 156. Totally 2402 elements are found.
# Round 157. Totally 2422 elements are found.
# Round 158. Totally 2442 elements are found.
# Round 159. Totally 2460 elements are found.
# Round 160. Totally 2476 elements are found.
# Round 161. Totally 2492 elements are found.
# Round 162. Totally 2512 elements are found.
# Round 163. Totally 2540 elements are found.
# Round 164. Totally 2564 elements are found.
# Round 165. Totally 2590 elements are found.
# Round 166. Totally 2610 elements are found.
# Round 167. Totally 2634 elements are found.
# Round 168. Totally 2660 elements are found.
# Round 169. Totally 2690 elements are found.
# Round 170. Totally 2718 elements are found.
# Round 171. Totally 2758 elements are found.
# Round 172. Totally 2786 elements are found.
# Round 173. Totally 2814 elements are found.
# Round 174. Totally 2844 elements are found.
# Round 175. Totally 2866 elements are found.
# Round 176. Totally 2884 elements are found.
# Round 177. Totally 2900 elements are found.
# Round 178. Totally 2912 elements are found.
# Round 179. Totally 2924 elements are found.
# Round 180. Totally 2932 elements are found.
# Round 181. Totally 2942 elements are found.
# Round 182. Totally 2952 elements are found.
# Round 183. Totally 2964 elements are found.
# Round 184. Totally 2976 elements are found.
# Round 185. Totally 2994 elements are found.
# Round 186. Totally 3012 elements are found.
# Round 187. Totally 3040 elements are found.
# Round 188. Totally 3072 elements are found.
# Round 189. Totally 3106 elements are found.
# Round 190. Totally 3142 elements are found.
# Round 191. Totally 3190 elements are found.
# Round 192. Totally 3224 elements are found.
# Round 193. Totally 3256 elements are found.
# Round 194. Totally 3290 elements are found.
# Round 195. Totally 3322 elements are found.
# Round 196. Totally 3352 elements are found.
# Round 197. Totally 3384 elements are found.
# Round 198. Totally 3420 elements are found.
# Round 199. Totally 3472 elements are found.
# Round 200. Totally 3512 elements are found.
# Round 201. Totally 3556 elements are found.
# Round 202. Totally 3596 elements are found.
# Round 203. Totally 3634 elements are found.
# Round 204. Totally 3676 elements are found.
# Round 205. Totally 3716 elements are found.
# Round 206. Totally 3756 elements are found.
# Round 207. Totally 3794 elements are found.
# Round 208. Totally 3822 elements are found.
# Round 209. Totally 3858 elements are found.
# Round 210. Totally 3886 elements are found.
# Round 211. Totally 3914 elements are found.
# Round 212. Totally 3946 elements are found.
# Round 213. Totally 3976 elements are found.
# Round 214. Totally 4012 elements are found.
# Round 215. Totally 4048 elements are found.
# Round 216. Totally 4090 elements are found.
# Round 217. Totally 4136 elements are found.
# Round 218. Totally 4176 elements are found.
# Round 219. Totally 4226 elements are found.
# Round 220. Totally 4274 elements are found.
# Round 221. Totally 4324 elements are found.
# Round 222. Totally 4386 elements are found.
# Round 223. Totally 4446 elements are found.
# Round 224. Totally 4508 elements are found.
# Round 225. Totally 4566 elements are found.
# Round 226. Totally 4628 elements are found.
# Round 227. Totally 4690 elements are found.
# Round 228. Totally 4750 elements are found.
# Round 229. Totally 4806 elements are found.
# Round 230. Totally 4854 elements are found.
# Round 231. Totally 4908 elements are found.
# Round 232. Totally 4972 elements are found.
# Round 233. Totally 5030 elements are found.
# Round 234. Totally 5090 elements are found.
# Round 235. Totally 5150 elements are found.
# Round 236. Totally 5225 elements are found.
# Round 237. Totally 5295 elements are found.
# Round 238. Totally 5359 elements are found.
# Round 239. Totally 5429 elements are found.
# Round 240. Totally 5495 elements are found.
# Round 241. Totally 5557 elements are found.
# Round 242. Totally 5619 elements are found.
# Round 243. Totally 5681 elements are found.
# Round 244. Totally 5737 elements are found.
# Round 245. Totally 5791 elements are found.
# Round 246. Totally 5843 elements are found.
# Round 247. Totally 5893 elements are found.
# Round 248. Totally 5927 elements are found.
# Round 249. Totally 5963 elements are found.
# Round 250. Totally 5999 elements are found.
# Round 251. Totally 6047 elements are found.
# Round 252. Totally 6103 elements are found.
# Round 253. Totally 6165 elements are found.
# Round 254. Totally 6217 elements are found.
# Round 255. Totally 6273 elements are found.
# Round 256. Totally 6324 elements are found.
# Round 257. Totally 6384 elements are found.
# Round 258. Totally 6428 elements are found.
# Round 259. Totally 6468 elements are found.
# Round 260. Totally 6518 elements are found.
# Round 261. Totally 6566 elements are found.
# Round 262. Totally 6612 elements are found.
# Round 263. Totally 6662 elements are found.
# Round 264. Totally 6718 elements are found.
# Round 265. Totally 6774 elements are found.
# Round 266. Totally 6824 elements are found.
# Round 267. Totally 6886 elements are found.
# Round 268. Totally 6948 elements are found.
# Round 269. Totally 7018 elements are found.
# Round 270. Totally 7084 elements are found.
# Round 271. Totally 7156 elements are found.
# Round 272. Totally 7226 elements are found.
# Round 273. Totally 7302 elements are found.
# Round 274. Totally 7374 elements are found.
# Round 275. Totally 7452 elements are found.
# Round 276. Totally 7526 elements are found.
# Round 277. Totally 7594 elements are found.
# Round 278. Totally 7652 elements are found.
# Round 279. Totally 7702 elements are found.
# Round 280. Totally 7756 elements are found.
# Round 281. Totally 7808 elements are found.
# Round 282. Totally 7862 elements are found.
# Round 283. Totally 7908 elements are found.
# Round 284. Totally 7948 elements are found.
# Round 285. Totally 7980 elements are found.
# Round 286. Totally 8016 elements are found.
# Round 287. Totally 8058 elements are found.
# Round 288. Totally 8096 elements are found.
# Round 289. Totally 8124 elements are found.
# Round 290. Totally 8152 elements are found.
# Round 291. Totally 8178 elements are found.
# Round 292. Totally 8212 elements are found.
# Round 293. Totally 8240 elements are found.
# Round 294. Totally 8270 elements are found.
# Round 295. Totally 8304 elements are found.
# Round 296. Totally 8344 elements are found.
# Round 297. Totally 8380 elements are found.
# Round 298. Totally 8420 elements are found.
# Round 299. Totally 8462 elements are found.
# Round 300. Totally 8502 elements are found.
# Round 301. Totally 8542 elements are found.
# Round 302. Totally 8588 elements are found.
# Round 303. Totally 8630 elements are found.
# Round 304. Totally 8666 elements are found.
# Round 305. Totally 8702 elements are found.
# Round 306. Totally 8744 elements are found.
# Round 307. Totally 8788 elements are found.
# Round 308. Totally 8830 elements are found.
# Round 309. Totally 8862 elements are found.
# Round 310. Totally 8898 elements are found.
# Round 311. Totally 8948 elements are found.
# Round 312. Totally 8990 elements are found.
# Round 313. Totally 9030 elements are found.
# Round 314. Totally 9078 elements are found.
# Round 315. Totally 9118 elements are found.
# Round 316. Totally 9156 elements are found.
# Round 317. Totally 9186 elements are found.
# Round 318. Totally 9216 elements are found.
# Round 319. Totally 9246 elements are found.
# Round 320. Totally 9276 elements are found.
# Round 321. Totally 9308 elements are found.
# Round 322. Totally 9346 elements are found.
# Round 323. Totally 9380 elements are found.
# Round 324. Totally 9422 elements are found.
# Round 325. Totally 9464 elements are found.
# Round 326. Totally 9496 elements are found.
# Round 327. Totally 9526 elements are found.
# Round 328. Totally 9558 elements are found.
# Round 329. Totally 9578 elements are found.
# Round 330. Totally 9604 elements are found.
# Round 331. Totally 9630 elements are found.
# Round 332. Totally 9650 elements are found.
# Round 333. Totally 9674 elements are found.
# Round 334. Totally 9696 elements are found.
# Round 335. Totally 9728 elements are found.
# Round 336. Totally 9752 elements are found.
# Round 337. Totally 9774 elements are found.
# Round 338. Totally 9798 elements are found.
# Round 339. Totally 9828 elements are found.
# Round 340. Totally 9864 elements are found.
# Round 341. Totally 9900 elements are found.
# Round 342. Totally 9930 elements are found.
# Round 343. Totally 9962 elements are found.
# Round 344. Totally 9984 elements are found.
# Round 345. Totally 10004 elements are found.
# Round 346. Totally 10020 elements are found.
# Round 347. Totally 10030 elements are found.
# Round 348. Totally 10040 elements are found.
# Round 349. Totally 10048 elements are found.
# Round 350. Totally 10058 elements are found.
# Round 351. Totally 10068 elements are found.
# Round 352. Totally 10074 elements are found.
# Round 353. Totally 10080 elements are found.
# Round 354. Totally 10088 elements are found.
# Round 355. Totally 10096 elements are found.
# Round 356. Totally 10104 elements are found.
# Round 357. Totally 10116 elements are found.
# Round 358. Totally 10126 elements are found.
# Round 359. Totally 10138 elements are found.
# Round 360. Totally 10146 elements are found.
# Round 361. Totally 10154 elements are found.
# Round 362. Totally 10162 elements are found.
# Round 363. Totally 10170 elements are found.
# Round 364. Totally 10178 elements are found.
# Round 365. Totally 10188 elements are found.
# Round 366. Totally 10202 elements are found.
# Round 367. Totally 10214 elements are found.
# Round 368. Totally 10228 elements are found.
# Round 369. Totally 10236 elements are found.
# Round 370. Totally 10244 elements are found.
# Round 371. Totally 10248 elements are found.
# Round 372. Totally 10252 elements are found.
# Round 373. Totally 10256 elements are found.
# Round 374. Totally 10258 elements are found.
# Round 375. Totally 10260 elements are found.
# Round 376. Totally 10262 elements are found.
# Round 377. Totally 10264 elements are found.
# cr: 1
# 77029108 [77029109 77029349]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 9 elements are found.
# Round 4. Totally 15 elements are found.
# Round 5. Totally 21 elements are found.
# Round 6. Totally 29 elements are found.
# Round 7. Totally 35 elements are found.
# Round 8. Totally 43 elements are found.
# Round 9. Totally 51 elements are found.
# Round 10. Totally 59 elements are found.
# Round 11. Totally 65 elements are found.
# Round 12. Totally 71 elements are found.
# Round 13. Totally 77 elements are found.
# Round 14. Totally 85 elements are found.
# Round 15. Totally 93 elements are found.
# Round 16. Totally 103 elements are found.
# Round 17. Totally 113 elements are found.
# Round 18. Totally 123 elements are found.
# Round 19. Totally 133 elements are found.
# Round 20. Totally 141 elements are found.
# Round 21. Totally 151 elements are found.
# Round 22. Totally 159 elements are found.
# Round 23. Totally 167 elements are found.
# Round 24. Totally 173 elements are found.
# Round 25. Totally 181 elements are found.
# Round 26. Totally 185 elements are found.
# Round 27. Totally 187 elements are found.
# Round 28. Totally 191 elements are found.
# Round 29. Totally 197 elements are found.
# Round 30. Totally 203 elements are found.
# Round 31. Totally 209 elements are found.
# Round 32. Totally 215 elements are found.
# Round 33. Totally 221 elements are found.
# Round 34. Totally 227 elements are found.
# Round 35. Totally 233 elements are found.
# Round 36. Totally 243 elements are found.
# Round 37. Totally 253 elements are found.
# Round 38. Totally 259 elements are found.
# Round 39. Totally 261 elements are found.
# cr: 2
# 77025120 [77025121 77026402]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# Round 5. Totally 11 elements are found.
# Round 6. Totally 13 elements are found.
# Round 7. Totally 15 elements are found.
# Round 8. Totally 17 elements are found.
# Round 9. Totally 19 elements are found.
# Round 10. Totally 21 elements are found.
# Round 11. Totally 23 elements are found.
# Round 12. Totally 25 elements are found.
# Round 13. Totally 27 elements are found.
# Round 14. Totally 29 elements are found.
# Round 15. Totally 33 elements are found.
# Round 16. Totally 37 elements are found.
# Round 17. Totally 39 elements are found.
# Round 18. Totally 41 elements are found.
# Round 19. Totally 43 elements are found.
# Round 20. Totally 45 elements are found.
# Round 21. Totally 47 elements are found.
# Round 22. Totally 49 elements are found.
# Round 23. Totally 51 elements are found.
# Round 24. Totally 53 elements are found.
# Round 25. Totally 55 elements are found.
# Round 26. Totally 57 elements are found.
# Round 27. Totally 59 elements are found.
# Round 28. Totally 61 elements are found.
# Round 29. Totally 63 elements are found.
# Round 30. Totally 65 elements are found.
# Round 31. Totally 67 elements are found.
# Round 32. Totally 69 elements are found.
# Round 33. Totally 71 elements are found.
# Round 34. Totally 73 elements are found.
# Round 35. Totally 77 elements are found.
# Round 36. Totally 83 elements are found.
# Round 37. Totally 89 elements are found.
# Round 38. Totally 97 elements are found.
# Round 39. Totally 105 elements are found.
# Round 40. Totally 111 elements are found.
# Round 41. Totally 117 elements are found.
# Round 42. Totally 127 elements are found.
# Round 43. Totally 139 elements are found.
# Round 44. Totally 151 elements are found.
# Round 45. Totally 167 elements are found.
# Round 46. Totally 185 elements are found.
# Round 47. Totally 201 elements are found.
# Round 48. Totally 215 elements are found.
# Round 49. Totally 232 elements are found.
# Round 50. Totally 248 elements are found.
# Round 51. Totally 262 elements are found.
# Round 52. Totally 274 elements are found.
# Round 53. Totally 286 elements are found.
# Round 54. Totally 302 elements are found.
# Round 55. Totally 322 elements are found.
# Round 56. Totally 340 elements are found.
# Round 57. Totally 356 elements are found.
# Round 58. Totally 374 elements are found.
# Round 59. Totally 392 elements are found.
# Round 60. Totally 418 elements are found.
# Round 61. Totally 442 elements are found.
# Round 62. Totally 468 elements are found.
# Round 63. Totally 490 elements are found.
# Round 64. Totally 512 elements are found.
# Round 65. Totally 540 elements are found.
# Round 66. Totally 566 elements are found.
# Round 67. Totally 592 elements are found.
# Round 68. Totally 614 elements are found.
# Round 69. Totally 630 elements are found.
# Round 70. Totally 648 elements are found.
# Round 71. Totally 670 elements are found.
# Round 72. Totally 688 elements are found.
# Round 73. Totally 706 elements are found.
# Round 74. Totally 724 elements are found.
# Round 75. Totally 740 elements are found.
# Round 76. Totally 758 elements are found.
# Round 77. Totally 772 elements are found.
# Round 78. Totally 790 elements are found.
# Round 79. Totally 812 elements are found.
# Round 80. Totally 832 elements are found.
# Round 81. Totally 856 elements are found.
# Round 82. Totally 884 elements are found.
# Round 83. Totally 912 elements are found.
# Round 84. Totally 938 elements are found.
# Round 85. Totally 970 elements are found.
# Round 86. Totally 1004 elements are found.
# Round 87. Totally 1040 elements are found.
# Round 88. Totally 1072 elements are found.
# Round 89. Totally 1096 elements are found.
# Round 90. Totally 1114 elements are found.
# Round 91. Totally 1136 elements are found.
# Round 92. Totally 1160 elements are found.
# Round 93. Totally 1184 elements are found.
# Round 94. Totally 1206 elements are found.
# Round 95. Totally 1228 elements are found.
# Round 96. Totally 1256 elements are found.
# Round 97. Totally 1280 elements are found.
# Round 98. Totally 1304 elements are found.
# Round 99. Totally 1326 elements are found.
# Round 100. Totally 1348 elements are found.
# Round 101. Totally 1372 elements are found.
# Round 102. Totally 1398 elements are found.
# Round 103. Totally 1424 elements are found.
# Round 104. Totally 1448 elements are found.
# Round 105. Totally 1474 elements are found.
# Round 106. Totally 1496 elements are found.
# Round 107. Totally 1516 elements are found.
# Round 108. Totally 1536 elements are found.
# Round 109. Totally 1565 elements are found.
# Round 110. Totally 1601 elements are found.
# Round 111. Totally 1637 elements are found.
# Round 112. Totally 1667 elements are found.
# Round 113. Totally 1697 elements are found.
# Round 114. Totally 1717 elements are found.
# Round 115. Totally 1733 elements are found.
# Round 116. Totally 1749 elements are found.
# Round 117. Totally 1769 elements are found.
# Round 118. Totally 1791 elements are found.
# Round 119. Totally 1805 elements are found.
# Round 120. Totally 1813 elements are found.
# Round 121. Totally 1823 elements are found.
# Round 122. Totally 1837 elements are found.
# Round 123. Totally 1857 elements are found.
# Round 124. Totally 1877 elements are found.
# Round 125. Totally 1895 elements are found.
# Round 126. Totally 1911 elements are found.
# Round 127. Totally 1927 elements are found.
# Round 128. Totally 1947 elements are found.
# Round 129. Totally 1975 elements are found.
# Round 130. Totally 1999 elements are found.
# Round 131. Totally 2025 elements are found.
# Round 132. Totally 2045 elements are found.
# Round 133. Totally 2069 elements are found.
# Round 134. Totally 2095 elements are found.
# Round 135. Totally 2125 elements are found.
# Round 136. Totally 2153 elements are found.
# Round 137. Totally 2193 elements are found.
# Round 138. Totally 2221 elements are found.
# Round 139. Totally 2249 elements are found.
# Round 140. Totally 2279 elements are found.
# Round 141. Totally 2301 elements are found.
# Round 142. Totally 2319 elements are found.
# Round 143. Totally 2335 elements are found.
# Round 144. Totally 2347 elements are found.
# Round 145. Totally 2359 elements are found.
# Round 146. Totally 2367 elements are found.
# Round 147. Totally 2377 elements are found.
# Round 148. Totally 2387 elements are found.
# Round 149. Totally 2399 elements are found.
# Round 150. Totally 2411 elements are found.
# Round 151. Totally 2429 elements are found.
# Round 152. Totally 2447 elements are found.
# Round 153. Totally 2475 elements are found.
# Round 154. Totally 2507 elements are found.
# Round 155. Totally 2541 elements are found.
# Round 156. Totally 2577 elements are found.
# Round 157. Totally 2625 elements are found.
# Round 158. Totally 2659 elements are found.
# Round 159. Totally 2691 elements are found.
# Round 160. Totally 2725 elements are found.
# Round 161. Totally 2757 elements are found.
# Round 162. Totally 2787 elements are found.
# Round 163. Totally 2819 elements are found.
# Round 164. Totally 2855 elements are found.
# Round 165. Totally 2907 elements are found.
# Round 166. Totally 2947 elements are found.
# Round 167. Totally 2991 elements are found.
# Round 168. Totally 3031 elements are found.
# Round 169. Totally 3069 elements are found.
# Round 170. Totally 3111 elements are found.
# Round 171. Totally 3151 elements are found.
# Round 172. Totally 3191 elements are found.
# Round 173. Totally 3229 elements are found.
# Round 174. Totally 3257 elements are found.
# Round 175. Totally 3293 elements are found.
# Round 176. Totally 3321 elements are found.
# Round 177. Totally 3349 elements are found.
# Round 178. Totally 3381 elements are found.
# Round 179. Totally 3411 elements are found.
# Round 180. Totally 3447 elements are found.
# Round 181. Totally 3483 elements are found.
# Round 182. Totally 3525 elements are found.
# Round 183. Totally 3571 elements are found.
# Round 184. Totally 3611 elements are found.
# Round 185. Totally 3661 elements are found.
# Round 186. Totally 3709 elements are found.
# Round 187. Totally 3759 elements are found.
# Round 188. Totally 3821 elements are found.
# Round 189. Totally 3881 elements are found.
# Round 190. Totally 3943 elements are found.
# Round 191. Totally 4001 elements are found.
# Round 192. Totally 4063 elements are found.
# Round 193. Totally 4125 elements are found.
# Round 194. Totally 4185 elements are found.
# Round 195. Totally 4241 elements are found.
# Round 196. Totally 4289 elements are found.
# Round 197. Totally 4343 elements are found.
# Round 198. Totally 4407 elements are found.
# Round 199. Totally 4465 elements are found.
# Round 200. Totally 4525 elements are found.
# Round 201. Totally 4585 elements are found.
# Round 202. Totally 4660 elements are found.
# Round 203. Totally 4730 elements are found.
# Round 204. Totally 4794 elements are found.
# Round 205. Totally 4864 elements are found.
# Round 206. Totally 4930 elements are found.
# Round 207. Totally 4992 elements are found.
# Round 208. Totally 5054 elements are found.
# Round 209. Totally 5116 elements are found.
# Round 210. Totally 5172 elements are found.
# Round 211. Totally 5226 elements are found.
# Round 212. Totally 5278 elements are found.
# Round 213. Totally 5328 elements are found.
# Round 214. Totally 5362 elements are found.
# Round 215. Totally 5398 elements are found.
# Round 216. Totally 5434 elements are found.
# Round 217. Totally 5482 elements are found.
# Round 218. Totally 5538 elements are found.
# Round 219. Totally 5600 elements are found.
# Round 220. Totally 5652 elements are found.
# Round 221. Totally 5708 elements are found.
# Round 222. Totally 5759 elements are found.
# Round 223. Totally 5819 elements are found.
# Round 224. Totally 5863 elements are found.
# Round 225. Totally 5903 elements are found.
# Round 226. Totally 5953 elements are found.
# Round 227. Totally 6001 elements are found.
# Round 228. Totally 6047 elements are found.
# Round 229. Totally 6097 elements are found.
# Round 230. Totally 6153 elements are found.
# Round 231. Totally 6209 elements are found.
# Round 232. Totally 6259 elements are found.
# Round 233. Totally 6321 elements are found.
# Round 234. Totally 6383 elements are found.
# Round 235. Totally 6453 elements are found.
# Round 236. Totally 6519 elements are found.
# Round 237. Totally 6591 elements are found.
# Round 238. Totally 6661 elements are found.
# Round 239. Totally 6737 elements are found.
# Round 240. Totally 6809 elements are found.
# Round 241. Totally 6887 elements are found.
# Round 242. Totally 6961 elements are found.
# Round 243. Totally 7029 elements are found.
# Round 244. Totally 7087 elements are found.
# Round 245. Totally 7137 elements are found.
# Round 246. Totally 7191 elements are found.
# Round 247. Totally 7243 elements are found.
# Round 248. Totally 7297 elements are found.
# Round 249. Totally 7343 elements are found.
# Round 250. Totally 7383 elements are found.
# Round 251. Totally 7415 elements are found.
# Round 252. Totally 7451 elements are found.
# Round 253. Totally 7493 elements are found.
# Round 254. Totally 7531 elements are found.
# Round 255. Totally 7559 elements are found.
# Round 256. Totally 7587 elements are found.
# Round 257. Totally 7613 elements are found.
# Round 258. Totally 7647 elements are found.
# Round 259. Totally 7675 elements are found.
# Round 260. Totally 7705 elements are found.
# Round 261. Totally 7739 elements are found.
# Round 262. Totally 7779 elements are found.
# Round 263. Totally 7815 elements are found.
# Round 264. Totally 7855 elements are found.
# ...
# Round 31. Totally 265 elements are found.
# Round 32. Totally 276 elements are found.
# Round 33. Totally 280 elements are found.
# Round 34. Totally 286 elements are found.
# Round 35. Totally 290 elements are found.
# Round 36. Totally 296 elements are found.
# Round 37. Totally 304 elements are found.
# Round 38. Totally 310 elements are found.
# Round 39. Totally 316 elements are found.
# Round 40. Totally 322 elements are found.
# Round 41. Totally 328 elements are found.
# Round 42. Totally 336 elements are found.
# Round 43. Totally 344 elements are found.
# Round 44. Totally 352 elements are found.
# Round 45. Totally 356 elements are found.
# Round 46. Totally 362 elements are found.
# Round 47. Totally 368 elements are found.
# Round 48. Totally 374 elements are found.
# Round 49. Totally 382 elements are found.
# Round 50. Totally 390 elements are found.
# Round 51. Totally 394 elements are found.
# Round 52. Totally 396 elements are found.
# Round 53. Totally 398 elements are found.
# Round 54. Totally 400 elements are found.
# Round 55. Totally 402 elements are found.
# Round 56. Totally 404 elements are found.
# Round 57. Totally 408 elements are found.
# Round 58. Totally 410 elements are found.
# Round 59. Totally 414 elements are found.
# Round 60. Totally 416 elements are found.
# Round 61. Totally 418 elements are found.
# Round 62. Totally 422 elements are found.
# Round 63. Totally 428 elements are found.
# Round 64. Totally 436 elements are found.
# Round 65. Totally 444 elements are found.
# Round 66. Totally 450 elements are found.
# Round 67. Totally 452 elements are found.
# ca: 50
# 77020877 [77020881 77021106]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 7 elements are found.
# Round 3. Totally 11 elements are found.
# Round 4. Totally 15 elements are found.
# Round 5. Totally 17 elements are found.
# Round 6. Totally 21 elements are found.
# Round 7. Totally 25 elements are found.
# Round 8. Totally 27 elements are found.
# Round 9. Totally 31 elements are found.
# Round 10. Totally 35 elements are found.
# Round 11. Totally 39 elements are found.
# Round 12. Totally 43 elements are found.
# Round 13. Totally 47 elements are found.
# Round 14. Totally 51 elements are found.
# Round 15. Totally 55 elements are found.
# Round 16. Totally 61 elements are found.
# Round 17. Totally 65 elements are found.
# Round 18. Totally 71 elements are found.
# Round 19. Totally 77 elements are found.
# Round 20. Totally 79 elements are found.
# Round 21. Totally 83 elements are found.
# ca: 51
# 77018550 [77018554 77019113]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 7 elements are found.
# Round 3. Totally 11 elements are found.
# Round 4. Totally 15 elements are found.
# Round 5. Totally 19 elements are found.
# Round 6. Totally 25 elements are found.
# Round 7. Totally 29 elements are found.
# Round 8. Totally 35 elements are found.
# Round 9. Totally 41 elements are found.
# Round 10. Totally 43 elements are found.
# Round 11. Totally 47 elements are found.
# ca: 52
# 77015929 [77018310 77018455]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 7 elements are found.
# Round 3. Totally 11 elements are found.
# Round 4. Totally 15 elements are found.
# Round 5. Totally 19 elements are found.
# Round 6. Totally 25 elements are found.
# Round 7. Totally 31 elements are found.
# Round 8. Totally 39 elements are found.
# Round 9. Totally 49 elements are found.
# Round 10. Totally 63 elements are found.
# Round 11. Totally 75 elements are found.
# Round 12. Totally 87 elements are found.
# Round 13. Totally 99 elements are found.
# Round 14. Totally 113 elements are found.
# Round 15. Totally 125 elements are found.
# Round 16. Totally 137 elements are found.
# Round 17. Totally 149 elements are found.
# Round 18. Totally 165 elements are found.
# Round 19. Totally 185 elements are found.
# Round 20. Totally 203 elements are found.
# Round 21. Totally 225 elements are found.
# Round 22. Totally 251 elements are found.
# Round 23. Totally 275 elements are found.
# Round 24. Totally 297 elements are found.
# Round 25. Totally 323 elements are found.
# Round 26. Totally 351 elements are found.
# Round 27. Totally 381 elements are found.
# Round 28. Totally 407 elements are found.
# Round 29. Totally 437 elements are found.
# Round 30. Totally 467 elements are found.
# Round 31. Totally 497 elements are found.
# Round 32. Totally 521 elements are found.
# Round 33. Totally 547 elements are found.
# Round 34. Totally 563 elements are found.
# Round 35. Totally 581 elements are found.
# Round 36. Totally 599 elements are found.
# Round 37. Totally 619 elements are found.
# Round 38. Totally 643 elements are found.
# Round 39. Totally 665 elements are found.
# Round 40. Totally 687 elements are found.
# Round 41. Totally 705 elements are found.
# Round 42. Totally 721 elements are found.
# Round 43. Totally 733 elements are found.
# Round 44. Totally 739 elements are found.
# Round 45. Totally 743 elements are found.
# Round 46. Totally 749 elements are found.
# Round 47. Totally 755 elements are found.
# Round 48. Totally 757 elements are found.
# Round 49. Totally 761 elements are found.
# ca: 53
# 77013202 [77013203 77014799]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 11 elements are found.
# Round 5. Totally 19 elements are found.
# Round 6. Totally 29 elements are found.
# Round 7. Totally 43 elements are found.
# Round 8. Totally 65 elements are found.
# Round 9. Totally 97 elements are found.
# Round 10. Totally 133 elements are found.
# Round 11. Totally 171 elements are found.
# Round 12. Totally 213 elements are found.
# Round 13. Totally 257 elements are found.
# Round 14. Totally 303 elements are found.
# Round 15. Totally 337 elements are found.
# Round 16. Totally 367 elements are found.
# Round 17. Totally 395 elements are found.
# Round 18. Totally 421 elements are found.
# Round 19. Totally 441 elements are found.
# Round 20. Totally 463 elements are found.
# Round 21. Totally 491 elements are found.
# Round 22. Totally 520 elements are found.
# Round 23. Totally 544 elements are found.
# Round 24. Totally 572 elements are found.
# Round 25. Totally 600 elements are found.
# Round 26. Totally 626 elements are found.
# Round 27. Totally 650 elements are found.
# Round 28. Totally 672 elements are found.
# Round 29. Totally 694 elements are found.
# Round 30. Totally 722 elements are found.
# Round 31. Totally 744 elements are found.
# Round 32. Totally 760 elements are found.
# Round 33. Totally 776 elements are found.
# Round 34. Totally 794 elements are found.
# Round 35. Totally 814 elements are found.
# Round 36. Totally 834 elements are found.
# Round 37. Totally 854 elements are found.
# Round 38. Totally 872 elements are found.
# Round 39. Totally 892 elements are found.
# Round 40. Totally 918 elements are found.
# Round 41. Totally 934 elements are found.
# Round 42. Totally 952 elements are found.
# Round 43. Totally 968 elements are found.
# Round 44. Totally 972 elements are found.
# Round 45. Totally 978 elements are found.
# Round 46. Totally 982 elements are found.
# Round 47. Totally 986 elements are found.
# Round 48. Totally 992 elements are found.
# Round 49. Totally 1000 elements are found.
# Round 50. Totally 1006 elements are found.
# Round 51. Totally 1014 elements are found.
# Round 52. Totally 1022 elements are found.
# Round 53. Totally 1028 elements are found.
# Round 54. Totally 1034 elements are found.
# Round 55. Totally 1040 elements are found.
# Round 56. Totally 1048 elements are found.
# Round 57. Totally 1054 elements are found.
# Round 58. Totally 1062 elements are found.
# Round 59. Totally 1070 elements are found.
# Round 60. Totally 1082 elements are found.
# Round 61. Totally 1090 elements are found.
# Round 62. Totally 1100 elements are found.
# Round 63. Totally 1108 elements are found.
# Round 64. Totally 1118 elements are found.
# Round 65. Totally 1128 elements are found.
# Round 66. Totally 1140 elements are found.
# Round 67. Totally 1154 elements are found.
# Round 68. Totally 1168 elements are found.
# Round 69. Totally 1186 elements are found.
# Round 70. Totally 1202 elements are found.
# Round 71. Totally 1218 elements are found.
# Round 72. Totally 1226 elements are found.
# Round 73. Totally 1234 elements are found.
# Round 74. Totally 1240 elements are found.
# Round 75. Totally 1251 elements are found.
# Round 76. Totally 1255 elements are found.
# Round 77. Totally 1261 elements are found.
# Round 78. Totally 1265 elements are found.
# Round 79. Totally 1271 elements are found.
# Round 80. Totally 1279 elements are found.
# Round 81. Totally 1285 elements are found.
# Round 82. Totally 1291 elements are found.
# Round 83. Totally 1297 elements are found.
# Round 84. Totally 1303 elements are found.
# Round 85. Totally 1311 elements are found.
# Round 86. Totally 1319 elements are found.
# Round 87. Totally 1327 elements are found.
# Round 88. Totally 1331 elements are found.
# Round 89. Totally 1337 elements are found.
# Round 90. Totally 1343 elements are found.
# Round 91. Totally 1349 elements are found.
# Round 92. Totally 1357 elements are found.
# Round 93. Totally 1365 elements are found.
# Round 94. Totally 1369 elements are found.
# Round 95. Totally 1371 elements are found.
# Round 96. Totally 1373 elements are found.
# Round 97. Totally 1375 elements are found.
# Round 98. Totally 1377 elements are found.
# Round 99. Totally 1379 elements are found.
# Round 100. Totally 1383 elements are found.
# Round 101. Totally 1385 elements are found.
# Round 102. Totally 1389 elements are found.
# Round 103. Totally 1391 elements are found.
# Round 104. Totally 1393 elements are found.
# Round 105. Totally 1397 elements are found.
# Round 106. Totally 1403 elements are found.
# Round 107. Totally 1411 elements are found.
# Round 108. Totally 1419 elements are found.
# Round 109. Totally 1425 elements are found.
# Round 110. Totally 1427 elements are found.
# ca: 54
# 77016048 [77016049 77017639]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# Round 5. Totally 11 elements are found.
# Round 6. Totally 13 elements are found.
# Round 7. Totally 15 elements are found.
# Round 8. Totally 19 elements are found.
# Round 9. Totally 23 elements are found.
# Round 10. Totally 27 elements are found.
# Round 11. Totally 33 elements are found.
# Round 12. Totally 37 elements are found.
# Round 13. Totally 41 elements are found.
# Round 14. Totally 45 elements are found.
# Round 15. Totally 49 elements are found.
# Round 16. Totally 51 elements are found.
# Round 17. Totally 53 elements are found.
# ca: 55
# 77005843 [77006004 77007812]
# Round 1. Totally 3 elements are found.
# ca: 56
# 77003468 [77003487 77003686]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 7 elements are found.
# Round 3. Totally 11 elements are found.
# Round 4. Totally 15 elements are found.
# Round 5. Totally 21 elements are found.
# Round 6. Totally 27 elements are found.
# Round 7. Totally 31 elements are found.
# Round 8. Totally 37 elements are found.
# Round 9. Totally 39 elements are found.
# Round 10. Totally 41 elements are found.
# Round 11. Totally 43 elements are found.
# Round 12. Totally 47 elements are found.
# Round 13. Totally 49 elements are found.
# ca: 57
# 77027607 [77027613 77028302]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# Round 5. Totally 11 elements are found.
# Round 6. Totally 13 elements are found.
# ca: 58
# 77016097 [77016099 77018230]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# Round 5. Totally 11 elements are found.
# Round 6. Totally 15 elements are found.
# Round 7. Totally 17 elements are found.
# Round 8. Totally 19 elements are found.
# ca: 59
# 77014074 [77014152 77015536]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# ca: 60
# 77028460 []
# ca: 61
# 77018386 [77016357 77017222]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# Round 5. Totally 11 elements are found.
# Round 6. Totally 15 elements are found.
# Round 7. Totally 19 elements are found.
# Round 8. Totally 21 elements are found.
# Round 9. Totally 23 elements are found.
# Round 10. Totally 27 elements are found.
# Round 11. Totally 31 elements are found.
# Round 12. Totally 35 elements are found.
# Round 13. Totally 43 elements are found.
# Round 14. Totally 49 elements are found.
# Round 15. Totally 53 elements are found.
# Round 16. Totally 59 elements are found.
# Round 17. Totally 65 elements are found.
# Round 18. Totally 69 elements are found.
# Round 19. Totally 73 elements are found.
# Round 20. Totally 77 elements are found.
# Round 21. Totally 81 elements are found.
# Round 22. Totally 85 elements are found.
# Round 23. Totally 87 elements are found.
# Round 24. Totally 89 elements are found.
# ca: 62
# 77016584 [77016843 77017970]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# ca: 63
# 77016405 [77016413 77017893]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 11 elements are found.
# Round 5. Totally 15 elements are found.
# Round 6. Totally 19 elements are found.
# Round 7. Totally 23 elements are found.
# Round 8. Totally 25 elements are found.
# Round 9. Totally 27 elements are found.
# ca: 64
# 77024636 []
# ca: 65
# 77005763 [77005766 77007535]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 9 elements are found.
# Round 4. Totally 13 elements are found.
# Round 5. Totally 15 elements are found.
# Round 6. Totally 19 elements are found.
# Round 7. Totally 25 elements are found.
# Round 8. Totally 29 elements are found.
# Round 9. Totally 33 elements are found.
# Round 10. Totally 37 elements are found.
# Round 11. Totally 41 elements are found.
# Round 12. Totally 43 elements are found.
# ca: 66
# 77010920 [77010922 77012629]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 7 elements are found.
# Round 4. Totally 9 elements are found.
# Round 5. Totally 13 elements are found.
# Round 6. Totally 19 elements are found.
# Round 7. Totally 23 elements are found.
# Round 8. Totally 29 elements are found.
# Round 9. Totally 31 elements are found.
# Round 10. Totally 33 elements are found.
# Round 11. Totally 37 elements are found.
# Round 12. Totally 41 elements are found.
# Round 13. Totally 43 elements are found.
# Round 14. Totally 45 elements are found.
# Round 15. Totally 47 elements are found.
# Round 16. Totally 49 elements are found.
# Round 17. Totally 53 elements are found.
# Round 18. Totally 57 elements are found.
# Round 19. Totally 59 elements are found.
# ca: 67
# 77014356 [77015282 77015483]
# Round 1. Totally 3 elements are found.
# ca: 68
# 77013772 [77013802 77014620]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# ca: 69
# 77011283 [77011317 77012997]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 5 elements are found.
# Round 3. Totally 9 elements are found.
# Round 4. Totally 13 elements are found.
# Round 5. Totally 15 elements are found.
# ca: 70
# 77011793 [77012770 77012871]
# Round 1. Totally 3 elements are found.
# ca: 71
# 77011793 [77012770 77012871]
# Round 1. Totally 3 elements are found.
# ca: 72
# 77011381 [77012488 77012651]
# Round 1. Totally 3 elements are found.
# ca: 73
# 77012726 []
# ca: 74
# 77010919 [77010926 77011194]
# Round 1. Totally 3 elements are found.
# Round 2. Totally 7 elements are found.
# Round 3. Totally 11 elements are found.
# Round 4. Totally 17 elements are found.
# Round 5. Totally 23 elements are found.
# Round 6. Totally 29 elements are found.
# Round 7. Totally 35 elements are found.
# Round 8. Totally 41 elements are found.
# Round 9. Totally 43 elements are found.
# Round 10. Totally 45 elements are found.
# Round 11. Totally 49 elements are found.
# Round 12. Totally 53 elements are found.
# Round 13. Totally 55 elements are found.
# ca: 75

# %%
# # Save select CA basins
gdf_sel = pd.concat([outlet_drainage_ids[i] for i in ['AMF','SBB','YRS','FTO']])
fig = plt.figure()
ax = plt.subplot(111, projection=ccrs.PlateCarree())
gdf_sel.plot(ax=ax)
ax.add_feature(cfeature.RIVERS, edgecolor='r', lw=.4, zorder=1)
ax.add_feature(cfeature.COASTLINE, edgecolor='k', lw=.6)
# gdf_sel = gdf_sel.set_crs('EPSG:4326')
# outshp = '/glade/work/elkoukah/inputs/domain/shapefile/northern_sierras_amf-sbb-yrs-fto.shp'
# gdf_sel.to_file(outshp, layer='Catchment', driver="GPKG")
gdf_ca_sel = pd.concat([outlet_drainage_ids[i] for i in ['AMF','SBB','YRS','FTO']])
from shapely.geometry import Polygon
gdf_ca_sel = gpd.GeoDataFrame({'basin':['Northern Sierras'], 'geometry':[Polygon(gdf_ca_sel.unary_union.exterior.coords)]}, crs='EPSG:4326')

# %%
gdf0 = gpd.GeoDataFrame()
for key in outlet_drainage_ids.keys():
    geoms = outlet_drainage_ids[key]['geometry']
    # geoms.append(outlet_drainage_ids[key]['geometry'])
    tmp = gpd.GeoDataFrame({'gage_id':[key]*geoms.size, 'geometry':geoms})
    gdf0 = pd.concat([gdf0,tmp])
gdf0 = gdf0.set_crs(epsg=4326)
gdf0_crs = gdf0.to_crs(ccrs.PlateCarree())
gdf0_proj = gdf0.to_crs("EPSG:5070")

gdf0_proj['area'] = gdf0_proj.area

gauges_sorted_area = gdf0_proj.groupby('gage_id').sum().sort_values('area', ascending=False,).index.values

# %%
gdf1 = gpd.GeoDataFrame()
for gauge_id in gauges_sorted_area:
    tmp = gdf0_crs[gdf0_crs['gage_id']==gauge_id]
    gdf1 = pd.concat([gdf1,tmp])

# %%
gdf1_base = pd.merge(gdf1, metrics_southwest_base, left_on='gage_id', right_index=True)
gdf1_opt = pd.merge(gdf1, metrics_southwest_opt, left_on='gage_id', right_index=True)

# %%
# gdf1_base.to_file('out/gdf1_base.shp', layer='Catchment', driver="GPKG")
gdf1_opt.to_file('out/gdf1_opt.shp', layer='Catchment', driver="GPKG")

# %%
# Factors influencing model performance

# %%
tdelta = slice('1980-10-01','2019-09-30')

# %%
def gen_polygon_mask(lats, lons, res, geom):
    gridcells = [Polygon(((x-res, y-res), 
                      (x-res, y+res), 
                      (x+res, y+res), 
                      (x+res,y-res), 
                      (x-res, y-res))) for x,y in zip(lons, lats)]
    ngrd = len(gridcells)
    mask = np.zeros((ngrd,), dtype=int)
    for ii in range(ngrd):
        mask[ii] = geom.intersects(gridcells[ii])
    return mask

import pickle
def ds_aave_polygon(ds,gdf):
    weightmap = xa.pixel_overlaps(ds,gdf)
    aggregated = xa.aggregate(ds, weightmap)
    ds_aave = aggregated.to_dataset()
    return ds_aave

# %%
metric_gauges = metrics_southwest_base.index

cols = ['area','p_prism', 'p_conus', 'rnet', 'snow']
catch_attrs = pd.DataFrame(np.zeros((len(metric_gauges),len(cols))), columns=cols, index=metric_gauges)

# %%
# basin area

# %%
# area of KGE
# gdf1_opt_metric = gdf1_opt.to_crs('EPSG:5070')
gdf1_area = gdf1.to_crs('EPSG:5070')
gdf1_area['area'] = gdf1_area.area

# %%
mopt = metrics_southwest_opt
mbase = metrics_southwest_base
for gaugeid in metric_gauges:
    gA = gdf1_area[gdf1_area['gage_id']==gaugeid]['area'].sum()
    catch_attrs.loc[gaugeid, 'area'] = gA
    mopt.loc[gaugeid, 'area'] = gA
    mbase.loc[gaugeid, 'area'] = gA

# %%
# ma_base = metrics_southwest_base['mkge']>0.5
# ma_opt = metrics_southwest_opt['mkge']>0.5
# g_opt = metrics_southwest_opt['gage_id'][ma_opt].values
# g_base = metrics_southwest_base['gage_id'][ma_base].values

# A = gdf1_metric['area'].sum()
# gdf1_metric[gdf1_metric['gage_id'].isin(g_opt)]['area'].sum()/A
# # gdf1_metric[gdf1_metric['gage_id'].isin(g_base)]['area'].sum()/A

# %%
dict_geoms = {}
for gaugeid in metric_gauges:
    print(gaugeid, 'processing...')
    geomi = gdf0[gdf0['gage_id']==gaugeid].unary_union
    dict_geoms[gaugeid] = geomi
# Out:
# 9034900 processing...
# 9035800 processing...
# 9035900 processing...
# 9047700 processing...
# 9065500 processing...
# 9066000 processing...
# 9066200 processing...
# 9066300 processing...
# 9081600 processing...
# 9107000 processing...
# 9210500 processing...
# 9223000 processing...
# 9306242 processing...
# 9312600 processing...
# 9352900 processing...
# 9378170 processing...
# 9378630 processing...
# 9386900 processing...
# 9404450 processing...
# 9430600 processing...
# 9447800 processing...
# 9480000 processing...
# 9484000 processing...
# 9484600 processing...
# 9492400 processing...
# 9494000 processing...
# 9497800 processing...
# 9497980 processing...
# 9505200 processing...
# 9505350 processing...
# 9505800 processing...
# 9508300 processing...
# 9510200 processing...
# 9512280 processing...
# 9513780 processing...
# 9429490 processing...
# 9427520 processing...
# 9426000 processing...
# 9423000 processing...
# 9421500 processing...
# 9415000 processing...
# 9402500 processing...
# 9402000 processing...
# 9382000 processing...
# 9380000 processing...
# 9379500 processing...
# 9355500 processing...
# 9328500 processing...
# 9315000 processing...
# 9306500 processing...
# 9302000 processing...
# 9260000 processing...
# 9251000 processing...
# 9234500 processing...
# 9217000 processing...
# 9211200 processing...
# 9180500 processing...
# 9180000 processing...
# 9152500 processing...
# 9127800 processing...
# 9124700 processing...
# 9109000 processing...
# 9095500 processing...
# 9072500 processing...
# AMF processing...
# AMN processing...
# ANM processing...
# ANT processing...
# ASP processing...
# ASS processing...
# ASV processing...
# CSN processing...
# CYO processing...
# DAV processing...
# EFC processing...
# ERS processing...
# EWR processing...
# FPL processing...
# FPR processing...
# FRD processing...
# FTO processing...
# FTP processing...
# KGC processing...
# KGF processing...
# KLO processing...
# KRB processing...
# KRI processing...
# KRK processing...
# KWT processing...
# MBS processing...
# MDP processing...
# MKM processing...
# MRC processing...
# MSS processing...
# NCD processing...
# NPH processing...
# OWL processing...
# PSH processing...
# RRH processing...
# SBB processing...
# SCC processing...
# SCU processing...
# SDT processing...
# SIS processing...
# SJF processing...
# SNS processing...
# SRS processing...
# SSP processing...
# STB processing...
# SVC processing...
# SWH processing...
# TLG processing...
# TLM processing...
# TLN processing...
# TNL processing...
# TRF processing...
# WFC processing...
# WWR processing...
# YBG processing...
# YBJ processing...
# YBS processing...
# YCB processing...
# YRS processing...

# %%
# pickle.dump(dict_geoms, open('gauge_geoms.pkl', 'wb'))
dict_geoms = pickle.load(open('gauge_geoms.pkl', 'rb'))

# %%
list_geoms = list(dict_geoms.values())
gdf_gauges = gpd.GeoDataFrame({'geometry':list(list_geoms)}, index=dict_geoms.keys()).set_crs(epsg=4326)

# %%
# PRISM precip

# %%
idir = '/glade/derecho/scratch/elkoukah/inputs/prism/postprocess/'
# tmean = xr.load_dataarray(idir+'tmean.nc')
ppt = xr.load_dataarray(idir+'ppt.nc')

ppt_mean = ppt.sel(time=tdelta).mean('time')

res = 0.04
dict_masks = {}
for gaugeid in metric_gauges:
    # print(gaugeid, 'processing...')
    # geomi = gdf0[gdf0['gage_id']==gaugeid].unary_union
    # gdfi = gpd.GeoDataFrame({'geometry':[geomi]}).set_crs(epsg=4326)
    gdfi = gdf_gauges.loc[[gaugeid]]
    minx, miny, maxx, maxy = gdfi.bounds.values[0]
    ppt_bb = ppt_mean.sel(lat=slice(miny-res,maxy+res), lon=slice(minx-res,maxx+res))
    # paave = ds_aave_polygon(ppt_bb, gdfi)
    # catch_attrs.loc[gaugeid, 'p_prism'] = paave['ppt'][0].data
    xx, yy = np.meshgrid(ppt_bb.lon, ppt_bb.lat)
    mask = gen_polygon_mask(yy.ravel(), xx.ravel(), res/2, gdfi['geometry'])
    dict_masks[gaugeid] = mask
    print(gaugeid, mask.sum(), 'processing...')
    paave = ppt_bb.stack(ngrd=('lat','lon')).sel(ngrd=(mask>0)).mean()
    catch_attrs.loc[gaugeid, 'p_prism'] = paave.data

# %%
# pickle.dump(dict_masks, open('gauge_masks_prism.pkl', 'wb'))
# dict_masks = pickle.load(open('gauge_geoms_prism.pkl', 'rb'))

# %%
# model

# %%
catch_attrs = pd.read_csv('catch_attrs.csv', index_col=0)

# %%
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
casename = 'CA_conus404_newsurfdata_asmo.opt_002'
files = sorted(glob.glob(archive_dir+casename+'/lnd/hist/'+casename+'.clm2.h0.*.nc'))
data_vars = ['RAIN', 'SNOW', 'FSA', 'FIRA']
def preprocess(ds):
    return ds[data_vars]
h0 = xr.open_mfdataset(files, parallel=True, preprocess=preprocess)
h0['lon'] = h0.lon-360

h0_ann = h0.sel(time=tdelta).mean('time').compute()

ca_gauges = gdf_gauges.index[64:]

# %%
res = 0.04
ppt_mdl = (h0_ann['RAIN']+h0_ann['SNOW'])
rnet = h0_ann['FSA']-h0_ann['FIRA']
ds_mdl = xr.Dataset({'ppt':ppt_mdl, 'rnet':rnet})
for gaugeid in ca_gauges:
    print(gaugeid, 'processing...')
    # geomi = gdf0[gdf0['gage_id']==gaugeid].unary_union
    # gdfi = gpd.GeoDataFrame({'geometry':[geomi]}).set_crs(epsg=4326)
    gdfi = gdf_gauges.loc[[gaugeid]]
    minx, miny, maxx, maxy = gdfi.bounds.values[0]
    mdl_bb = ds_mdl.sel(lat=slice(miny-res,maxy+res), lon=slice(minx-res,maxx+res))
    mdlaave = ds_aave_polygon(mdl_bb, gdfi)
    pmean = mdlaave['ppt'][0].data
    rnetmean = mdlaave['rnet'][0].data
    catch_attrs.loc[gaugeid, 'p_conus'] = pmean*(24*60**2)*365
    catch_attrs.loc[gaugeid, 'rnet'] = rnetmean
# Out:
# AMF processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# AMN processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# ANM processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# ANT processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# ASP processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# ASS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# ASV processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# CSN processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# CYO processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# DAV processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# EFC processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# ERS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# EWR processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# FPL processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# FPR processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# FRD processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# FTO processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# FTP processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KGC processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KGF processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KLO processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KRB processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KRI processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KRK processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# KWT processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# MBS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# MDP processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# MKM processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# MRC processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# MSS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# NCD processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# NPH processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# OWL processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# PSH processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# RRH processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SBB processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SCC processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SCU processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SDT processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SIS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SJF processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SNS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SRS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SSP processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# STB processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SVC processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# SWH processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# TLG processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# TLM processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# TLN processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# TNL processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# TRF processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# WFC processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# WWR processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# YBG processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# YBJ processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# YBS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# YCB processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# YRS processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!

# %%
# snowfall
res = 0.04
snow_mdl = h0_ann['SNOW']
for i,gaugeid in enumerate(ca_gauges):
    print(gaugeid, 'for', i, 'in', len(ca_gauges), mask.sum())
    gdfi = gdf_gauges.loc[[gaugeid]]
    minx, miny, maxx, maxy = gdfi.bounds.values[0]
    mdl_bb = snow_mdl.sel(lat=slice(miny-res,maxy+res), lon=slice(minx-res,maxx+res))
    # mdlaave = ds_aave_polygon(mdl_bb, gdfi)
    # snowmean = mdlaave['SNOW'][0].data
    xx,yy = np.meshgrid(mdl_bb.lon, mdl_bb.lat)
    mask = gen_polygon_mask(yy.ravel(), xx.ravel(), res/2, gdfi['geometry'])
    snowmean = mdl_bb.stack(ngrd=('lat','lon'))[mask>0].mean().data
    catch_attrs.loc[gaugeid, 'snow'] = snowmean*(24*60**2)*365
# Out:
# AMF for 0 in 59 880
# AMN for 1 in 59 378
# ANM for 2 in 59 96
# ANT for 3 in 59 49
# ASP for 4 in 59 26
# ASS for 5 in 59 19
# ASV for 6 in 59 61
# CSN for 7 in 59 20
# CYO for 8 in 59 124
# DAV for 9 in 59 69
# EFC for 10 in 59 20
# ERS for 11 in 59 89
# EWR for 12 in 59 615
# FPL for 13 in 59 91
# FPR for 14 in 59 411
# FRD for 15 in 59 123
# FTO for 16 in 59 39
# FTP for 17 in 59 715
# KGC for 18 in 59 37
# KGF for 19 in 59 9
# KLO for 20 in 59 299
# KRB for 21 in 59 1852
# KRI for 22 in 59 465
# KRK for 23 in 59 397
# KWT for 24 in 59 179
# MBS for 25 in 59 122
# MDP for 26 in 59 8
# MKM for 27 in 59 75
# MRC for 28 in 59 170
# MSS for 29 in 59 237
# NCD for 30 in 59 139
# NPH for 31 in 59 86
# OWL for 32 in 59 28
# PSH for 33 in 59 108
# RRH for 34 in 59 1187
# SBB for 35 in 59 181
# SCC for 36 in 59 1913
# SCU for 37 in 59 92
# SDT for 38 in 59 29
# SIS for 39 in 59 102
# SJF for 40 in 59 1466
# SNS for 41 in 59 341
# SRS for 42 in 59 214
# SSP for 43 in 59 165
# STB for 44 in 59 68
# SVC for 45 in 59 90
# SWH for 46 in 59 48
# TLG for 47 in 59 27
# TLM for 48 in 59 333
# TLN for 49 in 59 39
# TNL for 50 in 59 108
# TRF for 51 in 59 164
# WFC for 52 in 59 207
# WWR for 53 in 59 36
# YBG for 54 in 59 22
# YBJ for 55 in 59 68
# YBS for 56 in 59 23
# YCB for 57 in 59 35
# YRS for 58 in 59 21

# %%
archive_dir = '/glade/derecho/scratch/elkoukah/archive/'
casename = 'CR_conus404_asmo_newsurfdata_fanrootingdepth.002'
files = sorted(glob.glob(archive_dir+casename+'/lnd/hist/'+casename+'.clm2.h0.*.nc'))
data_vars = ['RAIN', 'SNOW', 'FSA', 'FIRA']
def preprocess(ds):
    return ds[data_vars]
h0 = xr.open_mfdataset(files, parallel=True, preprocess=preprocess)
h0['lon'] = h0.lon-360
h0_ann = h0.sel(time=tdelta).mean('time').compute()

# %%
import pickle
def ds_aave_polygon(ds,gdf):
    weightmap = xa.pixel_overlaps(ds,gdf,impl='dot_product')
    aggregated = xa.aggregate(ds,weightmap,impl='dot_product')
    ds_aave = aggregated.to_dataset()
    return ds_aave

# %%
res = 0.04
ppt_mdl = (h0_ann['RAIN']+h0_ann['SNOW'])
rnet = h0_ann['FSA']-h0_ann['FIRA']
ds_mdl = xr.Dataset({'ppt':ppt_mdl, 'rnet':rnet})
for gaugeid in cr_gauges:
    print(gaugeid, 'processing...')
    # geomi = gdf0[gdf0['gage_id']==gaugeid].unary_union
    # gdfi = gpd.GeoDataFrame({'geometry':[geomi]}).set_crs(epsg=4326)
    gdfi = gdf_gauges.loc[[gaugeid]]
    minx, miny, maxx, maxy = gdfi.bounds.values[0]
    mdl_bb = ds_mdl.sel(lat=slice(miny-res,maxy+res), lon=slice(minx-res,maxx+res))
    mdlaave = ds_aave_polygon(mdl_bb, gdfi)
    pmean = mdlaave['ppt'][0].data
    rnetmean = mdlaave['rnet'][0].data
    catch_attrs.loc[gaugeid, 'p_conus'] = pmean*(24*60**2)*365
    catch_attrs.loc[gaugeid, 'rnet'] = rnetmean
# Out:
# 9034900 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9035800 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9035900 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9047700 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9065500 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9066000 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9066200 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9066300 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9081600 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9107000 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9210500 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9223000 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9306242 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9312600 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9352900 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9378170 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9378630 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9386900 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9404450 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9430600 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9447800 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9480000 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9484000 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9484600 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9492400 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9494000 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9497800 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9497980 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9505200 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9505350 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9505800 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9508300 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9510200 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9512280 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9513780 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...
# success!
# aggregating ppt...
# aggregating rnet...
# all variables aggregated to polygons!
# 9429490 processing...
# creating polygons for each pixel...
# lat/lon bounds not found in dataset; they will be created.
# calculating overlaps between pixels and output polygons...

# %%
# snowfall
res = 0.04
cr_gauges = gdf_gauges.index[:64]
snow_mdl = h0_ann['SNOW']
for i,gaugeid in enumerate(cr_gauges):
    print(gaugeid, 'for', i, 'in', len(cr_gauges), mask.sum())
    gdfi = gdf_gauges.loc[[gaugeid]]
    minx, miny, maxx, maxy = gdfi.bounds.values[0]
    mdl_bb = snow_mdl.sel(lat=slice(miny-res,maxy+res), lon=slice(minx-res,maxx+res))
    # mdlaave = ds_aave_polygon(mdl_bb, gdfi)
    # snowmean = mdlaave['SNOW'][0].data
    xx,yy = np.meshgrid(mdl_bb.lon, mdl_bb.lat)
    mask = gen_polygon_mask(yy.ravel(), xx.ravel(), res/2, gdfi['geometry'])
    snowmean = mdl_bb.stack(ngrd=('lat','lon'))[mask>0].mean().data
    catch_attrs.loc[gaugeid, 'snow'] = snowmean*(24*60**2)*365
# Out:
# 9034900 for 0 in 64 6
# 9035800 for 1 in 64 6
# 9035900 for 2 in 64 7
# 9047700 for 3 in 64 11
# 9065500 for 4 in 64 7
# 9066000 for 5 in 64 7
# 9066200 for 6 in 64 7
# 9066300 for 7 in 64 4
# 9081600 for 8 in 64 4
# 9107000 for 9 in 64 51
# 9210500 for 10 in 64 36
# 9223000 for 11 in 64 44
# 9306242 for 12 in 64 37
# 9312600 for 13 in 64 15
# 9352900 for 14 in 64 24
# 9378170 for 15 in 64 25
# 9378630 for 16 in 64 6
# 9386900 for 17 in 64 5
# 9404450 for 18 in 64 23
# 9430600 for 19 in 64 24
# 9447800 for 20 in 64 24
# 9480000 for 21 in 64 71
# 9484000 for 22 in 64 28
# 9484600 for 23 in 64 15
# 9492400 for 24 in 64 106
# 9494000 for 25 in 64 19
# 9497800 for 26 in 64 131
# 9497980 for 27 in 64 67
# 9505200 for 28 in 64 51
# 9505350 for 29 in 64 36
# 9505800 for 30 in 64 40
# 9508300 for 31 in 64 61
# 9510200 for 32 in 64 15
# 9512280 for 33 in 64 44
# 9513780 for 34 in 64 25
# 9429490 for 35 in 64 24
# 9427520 for 36 in 64 31226
# 9426000 for 37 in 64 30166
# 9423000 for 38 in 64 827
# 9421500 for 39 in 64 28561
# 9415000 for 40 in 64 28404
# 9402500 for 41 in 64 900
# 9402000 for 42 in 64 23619
# 9382000 for 43 in 64 4490
# 9380000 for 44 in 64 284
# 9379500 for 45 in 64 18779
# 9355500 for 46 in 64 4008
# 9328500 for 47 in 64 601
# 9315000 for 48 in 64 340
# 9306500 for 49 in 64 7349
# 9302000 for 50 in 64 758
# 9260000 for 51 in 64 740
# 9251000 for 52 in 64 799
# 9234500 for 53 in 64 656
# 9217000 for 54 in 64 2845
# 9211200 for 55 in 64 1877
# 9180500 for 56 in 64 843
# 9180000 for 57 in 64 4278
# 9152500 for 58 in 64 852
# 9127800 for 59 in 64 1452
# 9124700 for 60 in 64 752
# 9109000 for 61 in 64 657
# 9095500 for 62 in 64 69
# 9072500 for 63 in 64 1521

# %%
# catch_attrs.to_csv('catch_attrs_snow.csv')
# catch_attrs.to_csv('catch_attrs_2.csv')

# %% [markdown]
# # Plot

# %%
import matplotlib.gridspec as gridspec

# %%
shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/WBD_14_HU2_Shape/WBDHU2.shp'
gdf_ucrb = gpd.read_file(shapefile)
gdf_ucrb_crs = gdf_ucrb.to_crs(ccrs.PlateCarree())

shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/WBD_15_HU2_Shape/WBDHU2.shp'
gdf_lcrb = gpd.read_file(shapefile)
gdf_lcrb_crs = gdf_lcrb.to_crs(ccrs.PlateCarree())

shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/WBD_18_HU2_Shape/WBDHU2.shp'
gdf_ca = gpd.read_file(shapefile)
gdf_ca_crs = gdf_ca.to_crs(ccrs.PlateCarree())

shapefile = '/glade/work/elkoukah/inputs/domain/shapefile/SWUS_studydomain_epsg4326.shp'
gdf_sw = gpd.read_file(shapefile)
gdf_sw_crs = gdf_sw.to_crs(ccrs.PlateCarree())

# %%
gdf1_base = gpd.read_file('out/gdf1_base.shp')
gdf1_opt = gpd.read_file('out/gdf1_opt.shp')

# %%
comids_ca = pd.read_csv('/glade/work/elkoukah/inputs/obs/CDEC_Stations_COMID.csv')
comids_ca = comids_ca.set_index('STA')
comids_ca = comids_ca.drop('CLD')
cdec_stations = comids_ca.index.values

ca_opt_metrics = pd.read_csv('./out/metrics_opt_ca_camels_101980-092020.csv', index_col=0)
ca_opt_metrics = ca_opt_metrics.loc[ca_opt_metrics.index.isin(cdec_stations)] # drop camels from CA
cr_opt_metrics = pd.read_csv('./out/metrics_opt_cr_101980-092020.csv', index_col=0)
metrics_southwest_opt = pd.concat([cr_opt_metrics, ca_opt_metrics])

ca_base_metrics = pd.read_csv('./out/metrics_base_ca_camels_101980-092020.csv', index_col=0)
ca_base_metrics = ca_base_metrics.loc[ca_base_metrics.index.isin(cdec_stations)] # drop camels from CA
cr_base_metrics = pd.read_csv('./out/metrics_base_cr_101980-092019.csv', index_col=0)
metrics_southwest_base = pd.concat([cr_base_metrics, ca_base_metrics])

# %%
# station used in optimization
camels_ucrb = ['9034900', '9035800', '9035900', '9047700', '9065500', '9066000', '9066200', '9066300', '9081600', '9107000', '9210500', '9223000', '9306242', '9312600', '9352900', '9378170', '9378630']
reclamation_ucrb = ['9379500', '9355500', '9306500', '9260000', '9251000', '9234500', '9217000', '9211200', '9180000', '9152500', '9127800', '9124700', '9109000', '9095500', '9072500']
sac_ca = ['AMA', 'AMF', 'AMK', 'AMN', 'ANT', 'ASV', 'DAV', 'FPL', 
          'FPR', 'FRD', 'FTC', 'FTM', 'FTO', 'FTP', 'MSS', 'PLK',
          'PSH', 'SBB', 'SCU', 'SDT', 'SIS', 'SMU', 'SQS', 'SVC', 
          'YBG', 'YBJ', 'YBM', 'YBS', 'YCB', 'YRS']

ma1 = metrics_southwest_base.index.isin([float(i) for i in camels_ucrb])*False
ma2 = metrics_southwest_base.index.isin([float(i) for i in reclamation_ucrb])
ma3 = metrics_southwest_base.index.isin(sac_ca)
st_used_in_opt = (ma1+ma2+ma3)

# %%
metrics_southwest_opt[~st_used_in_opt].describe()
# Out:
#             mkge         r2       beta      sigma       pbias        nse  \
# count  82.000000  82.000000  82.000000  46.000000   82.000000  82.000000
# mean    0.410419   0.807862  -0.028765   0.860860   -6.037295   0.087150
# std     0.552488   0.176658   0.371389   0.517826   71.780677   1.502297
# min    -1.619567   0.035924  -0.737220   0.006283  -99.999998  -7.769424
# 25%     0.061319   0.733627  -0.210077   0.477977  -47.455595   0.042613
# 50%     0.616344   0.869639  -0.055568   0.974226   -7.477969   0.556396
# 75%     0.824943   0.920696   0.020575   1.094666    2.854872   0.810961
# max     0.927521   0.968401   1.926944   2.172250  399.092042   0.901489
#
#           nse_wy     qsim_mean        lat         lon         alpha
# count  46.000000  8.500000e+01  85.000000   85.000000  3.600000e+01
# mean   -0.401118  5.878685e+01  37.000020 -114.402185  1.218462e+00
# std     3.408614  1.459454e+02   2.523430    5.452891  7.884518e-01
# min   -22.071864  1.756375e-07  31.355380 -124.099000  1.381385e-15
# 25%    -0.176328  2.830675e-01  34.674740 -119.449000  8.788156e-01
# 50%     0.240108  2.835804e+00  37.339430 -112.604380  9.966462e-01
# 75%     0.696348  2.728551e+01  38.858308 -110.166770  1.555235e+00
# max     0.913066  5.670346e+02  42.110490 -105.906400  3.505946e+00

# %%
def kge_boxplot(ax, data, ylabel=r"KGE$^{''}$", xlabel_flag=True):
    st_used_in_opt = (ma1+ma2+ma3)
    st_used_in_opt = st_used_in_opt[~nan_mask]

    # all gages
    colors = ['#045a8d','#b30000']
    c = colors[0]
    boxprops = dict(linestyle='-', linewidth=1, color=c)
    capprops = boxprops
    whiskerprops = boxprops
    flierprops = dict(marker='o', markerfacecolor=c, markersize=2,markeredgecolor='none')
    medianprops = dict(linestyle='-', linewidth=1, color=c)
    bpref = ax.boxplot(data[:, 0][:, None], flierprops=flierprops, medianprops=medianprops, boxprops=boxprops,
                      whiskerprops=whiskerprops, capprops=capprops)
    
    c = colors[1]
    boxprops = dict(linestyle='-', linewidth=1, color=c)
    capprops = boxprops
    whiskerprops = boxprops
    flierprops = dict(marker='o', markerfacecolor=c, markersize=2,markeredgecolor='none')
    medianprops = dict(linestyle='-', linewidth=1, color=c)
    bpopt = ax.boxplot(data[:, 1][:, None], flierprops=flierprops, 
                      medianprops=medianprops, boxprops=boxprops,
                      whiskerprops=whiskerprops, capprops=capprops,
                      positions=[1.25])
    
    # optimized gages
    c = colors[0]
    boxprops = dict(linestyle='-', linewidth=1, color=c)
    capprops = boxprops
    whiskerprops = boxprops
    flierprops = dict(marker='o', markerfacecolor=c, markersize=2,markeredgecolor='none')
    medianprops = dict(linestyle='-', linewidth=1, color=c)
    bpref = ax.boxplot(data[:, 0][:, None][st_used_in_opt], flierprops=flierprops, medianprops=medianprops, boxprops=boxprops,
                      whiskerprops=whiskerprops, capprops=capprops,
                      positions=[1.75])
    c = colors[1]
    boxprops = dict(linestyle='-', linewidth=1, color=c)
    capprops = boxprops
    whiskerprops = boxprops
    flierprops = dict(marker='o', markerfacecolor=c, markersize=2,markeredgecolor='none')
    medianprops = dict(linestyle='-', linewidth=1, color=c)
    bpopt = ax.boxplot(data[:, 1][:, None][st_used_in_opt], flierprops=flierprops, 
                      medianprops=medianprops, boxprops=boxprops,
                      whiskerprops=whiskerprops, capprops=capprops,
                      positions=[2.])
    
    # other gages
    c = colors[0]
    boxprops = dict(linestyle='-', linewidth=1, color=c)
    capprops = boxprops
    whiskerprops = boxprops
    flierprops = dict(marker='o', markerfacecolor=c, markersize=2,markeredgecolor='none')
    medianprops = dict(linestyle='-', linewidth=1, color=c)
    bpref = ax.boxplot(data[:, 0][:, None][~st_used_in_opt], flierprops=flierprops, medianprops=medianprops, boxprops=boxprops,
                      whiskerprops=whiskerprops, capprops=capprops,
                      positions=[2.5])
    c = colors[1]
    boxprops = dict(linestyle='-', linewidth=1, color=c)
    capprops = boxprops
    whiskerprops = boxprops
    flierprops = dict(marker='o', markerfacecolor=c, markersize=2,markeredgecolor='none')
    medianprops = dict(linestyle='-', linewidth=1, color=c)
    bpopt = ax.boxplot(data[:, 1][:, None][~st_used_in_opt], flierprops=flierprops, 
                      medianprops=medianprops, boxprops=boxprops,
                      whiskerprops=whiskerprops, capprops=capprops,
                      positions=[2.75])
    
    # ax.axvspan(0.8,1.7, color='grey', alpha=.15, zorder=-1)
    # ax.axvspan(1.8,2.7, color='tab:blue', alpha=.15, zorder=-1)
    
    # ax.set_xticks([1.25,2.25])
    # ax.set_xticklabels(['Reference', 'Optimized'])
    ax.set_xticks([1.12,1.87,2.62])
    if xlabel_flag:
        ax.set_xticklabels(['All basins', 'Optimized', 'Out-of-sample'], rotation=90)
    else:
        ax.set_xticklabels(['', '', ''], rotation=90)
    
    ax.set_ylabel(ylabel)
    return bpref,bpopt

# %%
dict_sens_cr = pickle.load(open('dict_sens_cr.pkl', 'rb'))
dict_sens_ca = pickle.load(open('dict_sens_ca.pkl', 'rb'))

# %%
# SENSITIVITY inputs

temp = pd.read_csv('catch_attrs_2.csv')
catch_attrs = temp.iloc[:-64]
temp2 = temp.iloc[-64:].set_index('Unnamed: 0')
catch_attrs.iloc[:64, -1] = temp2.loc[[str(g) for g in metrics_southwest_base.index[:64]]]['rnet'].values
catch_attrs = catch_attrs.set_index('Unnamed: 0')
temp_snow = pd.read_csv('catch_attrs_snow.csv', index_col=0)
catch_attrs['snow'] = temp_snow['snow']

mopt = metrics_southwest_opt
mbase = metrics_southwest_base
str_index = [str(i) for i in mopt.index]
mopt.index = str_index
catch_attrs['rnet_mm'] = catch_attrs['rnet']/(2.5*10**6)*86400*365
catch_attrs['qmean'] = mopt['qsim_mean']
catch_attrs['qmean_mm'] = (catch_attrs['qmean']/catch_attrs['area'])*1000*365*24*3600
catch_attrs = catch_attrs.loc[str_index]
# Out:
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
slopes = {}
dxx, dyy0, dyy, dxx0, dkk = dict_sens_cr['dxx'], dict_sens_cr['dyy0'], dict_sens_cr['dyy'], dict_sens_cr['dxx0'], dict_sens_cr['dkk']
slope_mdl0, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy0)[0]
slope_mdl, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy)[0]
slope_obs, _ = np.linalg.lstsq(np.stack([dxx0.data,np.ones(dxx0.size)]).T, dkk)[0]
print('cr', slope_mdl0, slope_mdl, slope_obs, (slope_mdl0-slope_obs)/slope_obs, (slope_mdl-slope_obs)/slope_obs)
slopes['cr'] = (slope_mdl0, slope_mdl, slope_obs)

dxx, dyy0, dyy, dxx0, dkk = dict_sens_ca['dxx'], dict_sens_ca['dyy0'], dict_sens_ca['dyy'], dict_sens_ca['dxx0'], dict_sens_ca['dkk']
slope_mdl0, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy0)[0]
slope_mdl, _ = np.linalg.lstsq(np.stack([dxx.data,np.ones(dxx.size)]).T, dyy)[0]
slope_obs, _ = np.linalg.lstsq(np.stack([dxx0.data,np.ones(dxx0.size)]).T, dkk)[0]
print('ca', slope_mdl0, slope_mdl, slope_obs, (slope_mdl0-slope_obs)/slope_obs, (slope_mdl-slope_obs)/slope_obs)
slopes['ca'] = (slope_mdl0, slope_mdl, slope_obs)
# Out:
# cr 0.9976963823169513 1.8320754444611005 1.5647443265441432 -0.3623901583203438 0.17084651682832963
# ca 1.4328263561861803 1.7940567176747948 1.5245120722340417 -0.06014102329377025 0.17680715708978184
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   after removing the cwd from sys.path.
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   # Remove the CWD from sys.path while we load stuff.
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   # This is added back by InteractiveShellApp.init_path()
# /glade/work/elkoukah/conda-envs/mynpl/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   if sys.path[0] == "":

# %%
cbar_ticks = {'mkge':np.arange(0., .91, .2),
              'sigma':np.array([0.5 , 0.75, 0.85, 1.15, 1.25, 1.5 ]),
              'beta':np.array([-0.5 , -0.25, -0.1, 0.1, 0.25, 0.5]),
              'r2':np.arange(0., .91, .2),}
labels = {'mkge':r"KGE$^{''}$",
          # 'mkge':r"modified Kling–Gupta efficiency (KGE$^{''}$)",
          'r2':'$r$',
          'sigma':r'$\alpha$',
          'beta':r'$\beta$',
         }
extent = (-124.6, -105.6, 30.02, 43.46)
df1, df2 = metrics_southwest_base, metrics_southwest_opt
metric = 'mkge'
cmap = 'RdBu' #'PiYG'
norm = matplotlib.colors.BoundaryNorm(boundaries=cbar_ticks[metric], ncolors=256, extend='both')
ticks = cbar_ticks[metric]
label = labels[metric]

# %%
fig = plt.figure(figsize=(8,8))

# MAP of KGE''
gs1 = gridspec.GridSpec(1,2)
gs1.update(left=0.,right=1.,top=1.,bottom=.75,wspace=0.1,hspace=0.25)

plot_gdfs = [gdf1_base, gdf1_opt]
titles = ['Reference', 'Optimized']
axes = []
states_provinces = cfeature.NaturalEarthFeature(category='cultural',
                                                name='admin_1_states_provinces_lines',
                                                scale='50m',
                                                facecolor='none')
for i in range(2):
    ax = plt.subplot(gs1[0,i],projection=ccrs.PlateCarree())
    ax.set_title(titles[i])
    axes += [ax]
    ax.add_feature(states_provinces, edgecolor='grey', lw=.4)
    ax.add_feature(cfeature.BORDERS, edgecolor='k', lw=.6)
    # ax.add_feature(cfeature.LAKES, edgecolor='grey', lw=.1)
    ax.add_feature(cfeature.COASTLINE, edgecolor='k', lw=.6)
    gdf_ucrb_crs.plot(ax=ax, lw=0.6, facecolor='None', edgecolor='k')
    gdf_lcrb_crs.plot(ax=ax, lw=0.6, facecolor='None', edgecolor='k')
    gdf_ca_crs.plot(ax=ax, lw=0.6, facecolor='None', edgecolor='k')
    gdf_sw_crs.plot(ax=ax, lw=0.6, facecolor='None', edgecolor='k')
    ax.set_extent(extent)
    plot_gdfs[i].plot(ax=ax, column='mkge', cmap=cmap, norm=norm, edgecolor='None', lw=0, zorder=-1)
    if i==0:
        gdf_ca_sel.plot(ax=ax, edgecolor='tab:green', facecolor='None',lw=.6)
        gdf_ucrb_crs.plot(ax=ax, edgecolor='tab:green', facecolor='None',lw=.6)
        ax.annotate('Northern Sierras', (.225,.925), xycoords='axes fraction', ha='left', color='tab:green', fontsize=10)
        ax.annotate('Upper Colorado', (.695,.725), xycoords='axes fraction', ha='right', color='tab:green', fontsize=10)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm._A = []
cb = plt.colorbar(sm, ax=axes,location='right',aspect=30, shrink=.8, ticks=ticks, extendfrac='auto', extendrect=True, pad=0.02)
cb.set_label(label)

# BOXPLOT
gs2 = gridspec.GridSpec(2,2)
gs2.update(left=0.,right=.4,top=.7,bottom=.45,wspace=0.45,hspace=0.25)
# for i in range(4):
#     j = [(0,0),(0,1),(1,0),(1,1)]
#     ax = plt.subplot(gs2[j[i][0], j[i][1]])

data = np.stack([df1['mkge'].values, df2['mkge'].values]).T
nan_mask = np.isnan(data).any(axis=1)
data = data[~nan_mask]
ax = plt.subplot(gs2[0,0])
bpref,bpopt = kge_boxplot(ax, data, ylabel=r"KGE$^{''}$", xlabel_flag=False)
ax.axhline(0.5, color='k', ls='--', lw=.5, zorder=-2)
ax.set_ylim(-2.25,1)
ax.set_yticks([-2,-1,0,0.5,1]);
ax.set_yticklabels([-2,-1,0,0.5,1]);
ax.legend([bpref["boxes"][0], bpopt["boxes"][0]], ['Reference','Optimized'], loc='upper center', ncol=2, bbox_to_anchor=(1.1,1.45))


data = np.stack([df1['r2'].values, df2['r2'].values]).T
nan_mask = np.isnan(data).any(axis=1)
data = data[~nan_mask]
ax = plt.subplot(gs2[0,1])
kge_boxplot(ax, data, ylabel=r"$r$", xlabel_flag=False)
ax.axhline(0.8, color='k', ls='--', lw=.5, zorder=-2)
ax.set_yticks([0,0.2,0.4,0.6,0.8,1]);

data = np.stack([df1['sigma'].values, df2['sigma'].values]).T
nan_mask = np.isnan(data).any(axis=1)
data = data[~nan_mask]
ax = plt.subplot(gs2[1,0])
kge_boxplot(ax, data, ylabel=r"$\alpha$")
ax.axhline(1, color='k', ls='--', lw=.5, zorder=-2)
# ax.set_yticks([0,0.2,0.4,0.6,0.8,1]);
ax.set_ylim(-0.1,3)

data = np.stack([df1['beta'].values, df2['beta'].values]).T
nan_mask = np.isnan(data).any(axis=1)
data = data[~nan_mask]
ax = plt.subplot(gs2[1,1])
kge_boxplot(ax, data, ylabel=r"$\beta$")
ax.axhline(0., color='k', ls='--', lw=.5, zorder=-2)
# ax.set_yticks([0,0.2,0.4,0.6,0.8,1]);
ax.set_ylim(-.7,3)

# SCATTERPLOT
gs3 = gridspec.GridSpec(1,3)
gs3.update(left=0.525,right=1.,top=.7,bottom=.38,wspace=0.1,hspace=0.25)
# for i in range(3):
#     ax = plt.subplot(gs3[0,i])
ax = plt.subplot(gs3[0,0])
x,y = catch_attrs['area']/10**6/10**4, mopt['mkge']
ax.scatter(x[~st_used_in_opt],y[~st_used_in_opt], color='tab:red', alpha=.85, edgecolor='k', lw=.5, s=20, label='Out-of-sample basins')
ax.scatter(x[st_used_in_opt],y[st_used_in_opt], marker='*', color='white', alpha=.75, edgecolor='k', lw=.5, s=50, label='Optimized basins')
ax.set_ylabel(r"KGE$^{''}$ (-)")
ax.set_xlabel('Gauge Drainage Area \n(10$^4$ km$^2$)')
ax.legend(loc='upper center', ncol=2, bbox_to_anchor=(1.45,1.145))

ax = plt.subplot(gs3[0,1])
x,y = catch_attrs['rnet_mm']/catch_attrs['p_conus'], mopt['mkge']
# x,y = catch_attrs['snow']/catch_attrs['p_conus'], mopt['mkge']
ax.scatter(x[~st_used_in_opt],y[~st_used_in_opt], color='tab:red', alpha=.85, edgecolor='k', lw=.5, s=20)
ax.scatter(x[st_used_in_opt],y[st_used_in_opt], marker='*', color='white', alpha=.75, edgecolor='k', lw=.5, s=50)
# ax.scatter(catch_attrs['rnet_mm']/catch_attrs['p_conus'], mopt['mkge'], color='tab:red', alpha=.85, edgecolor='k', lw=.75, s=60)
ax.set_ylabel('')
ax.set_yticklabels([])
ax.set_xlabel(r'R$_{net}$/P (-)')
ax.axvline(.5, color='k', ls='--', lw=.5, zorder=-2)

ax = plt.subplot(gs3[0,2])
x,y = catch_attrs['p_conus']/(catch_attrs['p_prism']*12), mopt['mkge']
ax.scatter(x[~st_used_in_opt],y[~st_used_in_opt], color='tab:red', alpha=.85, edgecolor='k', lw=.5, s=20, label='Other gauges')
ax.scatter(x[st_used_in_opt],y[st_used_in_opt], marker='*', color='white', alpha=.75, edgecolor='k', lw=.5, s=50, label='Optimized gauges')
# ax.scatter(catch_attrs['p_conus']/(catch_attrs['p_prism']*12), mopt['mkge'], color='tab:red', alpha=.85, edgecolor='k', lw=.75, s=60)
ax.set_ylabel('')
ax.set_yticklabels([])
ax.set_xlabel(r'P$_{CONUS404}$/P$_{PRISM}$ (-)')
ax.axvline(1, color='k', ls='--', lw=.5, zorder=-2)


# HYDROGRAPH & SENSITIVITITY
gs4 = gridspec.GridSpec(1,4)
gs4.update(left=0.,right=1.,top=.25,bottom=.0,wspace=0.65,hspace=0.25)
## upper Colorado
ax = plt.subplot(gs4[0,0])
tdelta = slice('1981-10-01', '2019-09-30')
yy = dict_sens_cr['q_mdl'].sel(time=tdelta).groupby('time.month').mean()
yy0 = dict_sens_cr['q_mdl_base'].sel(time=tdelta).groupby('time.month').mean()
kk = dict_sens_cr['q_obs'].sel(time=tdelta).groupby('time.month').mean()
months = np.arange(12)
idx = np.append(months[9:],months[:9])
ax.plot(kk.data[idx], c='k', lw=1.2, label='Observed')
ax.plot(yy0.data[idx], c='tab:blue', lw=1, label='Reference')
ax.plot(yy.data[idx], c='tab:red', lw=1, label='Optimized')
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticks(months)
ax.set_xticklabels(['O','N','D', 'J','F','M','A','M','J','J','A','S',]);
ax.margins(x=0)
ax.set_ylim(0)
ax.set_ylabel('Monthly streamflow ($m^3/s$)')
ax.set_title('Upper Colorado')
# ax.legend(*ax.get_legend_handles_labels())


ax = plt.subplot(gs4[0,1])
sns.regplot(x=dict_sens_cr['dxx0'], y=dict_sens_cr['dkk'], ax=ax, color='k', truncate=True,
            scatter_kws={'s':10}, label='Observed');
sns.regplot(x=dict_sens_cr['dxx'], y=dict_sens_cr['dyy0'], ax=ax, color='tab:blue', truncate=True,
            scatter_kws={'s':10}, label='Reference');
sns.regplot(x=dict_sens_cr['dxx'], y=dict_sens_cr['dyy'], ax=ax, color='tab:red', truncate=True,
            scatter_kws={'s':10}, label='Optimized');
ax.set_ylabel(r'Streamflow (%)')
ax.set_xlabel(r'Precipitation (%)')
ax.set_title('Upper Colorado')
ax.tick_params(which='minor',length=3);   # dont show minor ticks; only labels
slope_mdl0, slope_mdl, slope_obs = slopes['cr']
ax.annotate(r"slope=%.2f"%slope_obs, (0.4,0.25), color='k', xycoords='axes fraction')
ax.annotate(r"slope=%.2f"%slope_mdl0, (0.4,0.18), color='tab:blue', xycoords='axes fraction')
ax.annotate(r"slope=%.2f"%slope_mdl, (0.4,0.11), color='tab:red', xycoords='axes fraction')

## California
ax = plt.subplot(gs4[0,2])
tdelta = slice('1981-10-01', '2019-09-30')
yy = dict_sens_ca['qopt'].sel(time=tdelta).groupby('time.month').mean()
yy0 = dict_sens_ca['qbase'].sel(time=tdelta).groupby('time.month').mean()
kk = dict_sens_ca['qobs'].sel(time=tdelta).groupby('time.month').mean()
months = np.arange(12)
idx = np.append(months[9:],months[:9])
ax.plot(kk.data[idx], c='k', lw=1.2, label='Observed discharge')
ax.plot(yy0.data[idx], c='tab:blue', lw=1, label='Simulated (reference)')
ax.plot(yy.data[idx], c='tab:red', lw=1, label='Simulated (optimized)')
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticks(months)
ax.set_xticklabels(['O','N','D', 'J','F','M','A','M','J','J','A','S',]);
ax.margins(x=0)
ax.set_ylim(0)
ax.set_ylabel('Monthly streamflow ($m^3/s$)')
ax.set_title('Northern Sierras')

ax = plt.subplot(gs4[0,3])
sns.regplot(x=dict_sens_ca['dxx0'], y=dict_sens_ca['dkk'], ax=ax, color='k', truncate=True,
            scatter_kws={'s':10}, label='Observed');
sns.regplot(x=dict_sens_ca['dxx'], y=dict_sens_ca['dyy0'], ax=ax, color='tab:blue', truncate=True,
            scatter_kws={'s':10}, label='Simulated (refrence)');
sns.regplot(x=dict_sens_ca['dxx'], y=dict_sens_ca['dyy'], ax=ax, color='tab:red', truncate=True,
            scatter_kws={'s':10}, label='Simulated (optimized)');
ax.set_ylabel(r'Streamflow (%)')
ax.set_xlabel(r'Precipitation (%)')
ax.set_title('Northern Sierras')
ax.tick_params(which='minor',length=3);   # dont show minor ticks; only labels
slope_mdl0, slope_mdl, slope_obs = slopes['ca']
ax.annotate(r"slope=%.2f"%slope_obs, (0.4,0.25), color='k', xycoords='axes fraction')
ax.annotate(r"slope=%.2f"%slope_mdl0, (0.4,0.18), color='tab:blue', xycoords='axes fraction')
ax.annotate(r"slope=%.2f"%slope_mdl, (0.4,0.11), color='tab:red', xycoords='axes fraction')

fig.text(-0.1, 1, 'a)', fontsize=16)
fig.text(-0.1, .7, 'b)', fontsize=16)
fig.text(.45, .7, 'c)', fontsize=16)
fig.text(-0.1, .275, 'd)', fontsize=16)
# Out:
# Text(-0.1, 0.275, 'd)')

# %%
fig.savefig('figs/streamflow_sim_v02.png', dpi=300, bbox_inches='tight')
